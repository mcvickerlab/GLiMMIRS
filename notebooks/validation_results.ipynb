# %%
import pandas as pd 
import numpy as np

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white');
plt.rcParams['figure.figsize'] = (15, 7)

# higher resolution plots
# %config InlineBackend.figure_format ='retina'

# %%
at_scale_general_validations = pd.read_csv('../results/at_scale_general_ts_gene_validations.csv')
at_scale_general_validations.head()
# Out:
#            0         1         2         3         4         5          6  \
# 0  11.598012  1.337784  0.014078  0.045615 -0.033472 -0.020128  11.595817
# 1   9.863513 -1.409941  0.062590  0.006316  0.050058 -0.014138   9.841740
# 2  10.168818  0.965907 -0.105410  0.045100 -0.061989 -0.023969  10.219432
# 3  12.041624  0.674360 -0.089185  0.054900  0.001991 -0.023671  12.034567
# 4  12.173551  0.804599 -0.098214  0.025255 -0.022811 -0.031938  12.200978
#
#           7         8         9        10        11        12           13  \
# 0  0.018936  1.337989  0.013807  0.045755 -0.033486 -0.020140 -3931.862997
# 1  0.094937 -1.408827  0.068009  0.006487  0.051210 -0.012983 -1463.812132
# 2 -0.357777  1.011425 -0.107897  0.037976 -0.064997 -0.024523 -1672.639283
# 3  0.083104  0.675446 -0.089901  0.055213  0.002657 -0.023468 -4634.004727
# 4 -0.153378  0.814311 -0.098512  0.023572 -0.022279 -0.030508 -5559.953632
#
#             14        15        16
# ...

# %%
p_values = at_scale_general_validations.iloc[:, -2]
p_values.plot(kind='hist');
