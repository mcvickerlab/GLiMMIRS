# %%
# import data analysis packages
import numpy as np
import pandas as pd

# file and command line packages
import os
import subprocess
import gzip

# string parsing
import re

# sparse matrix packages
from scipy.io import mmread

# modeling
from scipy.stats import nbinom

# %% [markdown]
# ### Load in Group and Sequence Data

# %%
# load in group sequence dataframe
group_sequence_df = pd.read_csv('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_grna_groups.at_scale.txt', 
                                sep='\t', names=['gRNA_group', 'spacer_sequence'])
group_sequence_df.head()
# Out:
#      gRNA_group       spacer_sequence
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG
# 1  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG
# 2    FAM83A_TSS  AACACACCACGGAGGAGTGG
# 3    ZNF593_TSS  AACAGCCCGGCCGGCCAAGG
# 4    ATPIF1_TSS  AACGAGAGACTGCTTGCTGG

# %%
# check dataframe shape
group_sequence_df.shape
# Out:
# (13189, 2)

# %%
# check dataframe missingness
group_sequence_df.isna().sum()
# Out:
# gRNA_group         0
# spacer_sequence    0
# dtype: int64

# %%
# check to ensure that there are no duplicates in the file
group_sequence_df.drop_duplicates().shape
# Out:
# (13189, 2)

# %%
# check if there are two guides per gRNA group
(group_sequence_df.groupby('gRNA_group').count()['spacer_sequence'] != 2).sum()
# Out:
# 7

# %%
# see groups where there are not 2 guides
df = group_sequence_df.groupby('gRNA_group').count()
df[df['spacer_sequence'] != 2]
# Out:
#                                           spacer_sequence
# gRNA_group
# bassik_mch                                              1
# pos_control_Klannchr1_HBG1_HBG1_tss_both                1
# pos_control_Klannchr1_HS3                               1
# pos_control_Klannchr1_HS4                               1
# pos_control_Klannchr_HS1                                1
# pos_control_mosaic_HB_HBE1_tss_A                        1
# pos_control_mosaic_HB_HBE1_tss_B                        1

# %% [markdown]
# ### Use BLAST to determine Genomic Coordinates from Sequence

# %% [markdown]
# Using BLAST to determine the genomic coordinates involves some preparation steps. First, the reference genome assembly (GRCh37) must be converted from a FASTA file to a BLAST database for alignment. This is because this genome assembly is not provided in the preformatted BLAST databases. This can be done using the makeblastdb command. After this db is created, it can now be used to determine the genomic coordinates.
#
# There are many parameters that are specified in the BLAST search. The db parameter is a path to where the db is stored (where makeblastdb was run) plus "/hg19". The query parameter is the input FASTA file, which contains the sequence to be queried by the BLAST db. The task parameter is especially important, since the guide sequences are shorter, this parameter adjusts other search parameters to yield results for the guide search (without this parameter, BLAST will not find any hits!). The outfmt parameter tells BLAST to return tabular output (specified by 6), and states the specific columns that BLAST should return from the search. This is for easier parsing using pandas. Finally, the out parameter is the filepath to where the output should be stored from BLAST.

# %%
# print BLAST help menu (for reference)
print((subprocess.run(["blastn", "-h"], capture_output=True).stdout).decode("utf-8"))
# Out:
# USAGE
#   blastn [-h] [-help] [-import_search_strategy filename]
#     [-export_search_strategy filename] [-task task_name] [-db database_name]
#     [-dbsize num_letters] [-gilist filename] [-seqidlist filename]
#     [-negative_gilist filename] [-entrez_query entrez_query]
#     [-db_soft_mask filtering_algorithm] [-db_hard_mask filtering_algorithm]
#     [-subject subject_input_file] [-subject_loc range] [-query input_file]
#     [-out output_file] [-evalue evalue] [-word_size int_value]
#     [-gapopen open_penalty] [-gapextend extend_penalty]
#     [-perc_identity float_value] [-qcov_hsp_perc float_value]
#     [-max_hsps int_value] [-xdrop_ungap float_value] [-xdrop_gap float_value]
#     [-xdrop_gap_final float_value] [-searchsp int_value]
#     [-sum_stats bool_value] [-penalty penalty] [-reward reward] [-no_greedy]
#     [-min_raw_gapped_score int_value] [-template_type type]
#     [-template_length int_value] [-dust DUST_options]
#     [-filtering_db filtering_database]
#     [-window_masker_taxid window_masker_taxid]
#     [-window_masker_db window_masker_db] [-soft_masking soft_masking]
#     [-ungapped] [-culling_limit int_value] [-best_hit_overhang float_value]
#     [-best_hit_score_edge float_value] [-window_size int_value]
#     [-off_diagonal_range int_value] [-use_index boolean] [-index_name string]
#     [-lcase_masking] [-query_loc range] [-strand strand] [-parse_deflines]
#     [-outfmt format] [-show_gis] [-num_descriptions int_value]
#     [-num_alignments int_value] [-line_length line_length] [-html]
#     [-max_target_seqs num_sequences] [-num_threads int_value] [-remote]
#     [-version]
#
# DESCRIPTION
#    Nucleotide-Nucleotide BLAST 2.5.0+
#
# Use '-help' to print detailed descriptions of command line arguments

# %%
def create_fasta(sequence):
    '''helper function to create FASTA file given input sequence'''
    
    # open file and write sequence to BLAST folder
    filename = sequence + '.fasta'
    filepath = './../blast/input/' + filename
    with open(filepath, 'w') as f:
        f.write(sequence + '\n')

# %%
def run_blast(file):
    '''helper function to get genomic coordinates from BLAST output'''
    
    # define BLAST command line arguments
    sequence = file.split('.')[0]
    blast_args = ["blastn", "-db", "../../blast/hg19", "-query", '../blast/input/' + file, "-task", "blastn-short", 
                  '-outfmt', '6 sseqid evalue sstart send', '-out', '../blast/output/' + sequence + '.tsv']
    
    # run BLAST
    subprocess.run(blast_args)

# %%
# create FASTA files for each spacer sequence
group_sequence_df['spacer_sequence'].apply(create_fasta)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 13184    None
# 13185    None
# 13186    None
# 13187    None
# 13188    None
# Name: spacer_sequence, Length: 13189, dtype: object

# %% [markdown]
# After generating the FASTA files, the next step is to run BLAST on each FASTA file to determine the genomic coordinates of the guide. BLAST can be run using the run_blast.py script under the "scripts" folder. This is done using the run_blast function defined above, but in a for loop for each FASTA file.

# %%
# test getting start and end coordinates for single BLAST query
colnames = ['chrom', 'evalue', 'start', 'end']
hits_df = pd.read_csv('../blast/output/AAAAAAAAGGTTAAGAGTAG.tsv', sep='\t', names=colnames)
sorted_hits_df = hits_df.sort_values(by='evalue', ascending=True)
print(sorted_hits_df.iloc[0]['start'])
print(sorted_hits_df.iloc[0]['end'])
# Out:
# 52946190
# 52946209

# %%
# preview group sequence dataframe
group_sequence_df.head()
# Out:
#      gRNA_group       spacer_sequence
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG
# 1  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG
# 2    FAM83A_TSS  AACACACCACGGAGGAGTGG
# 3    ZNF593_TSS  AACAGCCCGGCCGGCCAAGG
# 4    ATPIF1_TSS  AACGAGAGACTGCTTGCTGG

# %%
def get_genomic_coordinates(seq):
    '''helper function to get genomic coordinates from BLAST output'''
    
    # load in BLAST hits and sort by evalue
    colnames = ['chrom' ,'evalue', 'start', 'end']
    hits_df = pd.read_csv('../blast/output/' + seq + '.tsv', sep='\t', names=colnames)
    sorted_hits_df = hits_df.sort_values(by='evalue', ascending=True)
    
    # return start and end coordinates from BLAST
    if sorted_hits_df.shape[0] == 0:
        return [np.nan, np.nan, np.nan, np.nan]
    else:    
        start_coord = sorted_hits_df.iloc[0]['start']
        end_coord = sorted_hits_df.iloc[0]['end']
        chrom = sorted_hits_df.iloc[0]['chrom']
        evalue = sorted_hits_df.iloc[0]['evalue']
        return [start_coord, end_coord, chrom, evalue]

# %%
# get genomic coordinates for each spacer sequence
group_sequence_df['genomic_coords'] = group_sequence_df['spacer_sequence'].apply(get_genomic_coordinates)

# %%
# divide output into start and end columns
group_sequence_df['start'] = group_sequence_df['genomic_coords'].apply(lambda x: x[0])
group_sequence_df['end'] = group_sequence_df['genomic_coords'].apply(lambda x: x[1])
group_sequence_df['chrom'] = group_sequence_df['genomic_coords'].apply(lambda x: x[2])
group_sequence_df['evalue'] = group_sequence_df['genomic_coords'].apply(lambda x: x[3])
group_sequence_df.head()
# Out:
#      gRNA_group       spacer_sequence                       genomic_coords  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG    [26606551, 26606569, chr1, 0.032]
# 1  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   [10530445, 10530427, chr11, 0.032]
# 2    FAM83A_TSS  AACACACCACGGAGGAGTGG  [124195027, 124195008, chr8, 0.008]
# 3    ZNF593_TSS  AACAGCCCGGCCGGCCAAGG    [26496467, 26496448, chr1, 0.008]
# 4    ATPIF1_TSS  AACGAGAGACTGCTTGCTGG    [28562642, 28562660, chr1, 0.032]
#
#          start          end  chrom  evalue
# 0   26606551.0   26606569.0   chr1   0.032
# 1   10530445.0   10530427.0  chr11   0.032
# 2  124195027.0  124195008.0   chr8   0.008
# 3   26496467.0   26496448.0   chr1   0.008
# 4   28562642.0   28562660.0   chr1   0.032

# %%
# analyze missingness in coordinates data
group_sequence_df.isna().sum()
# Out:
# gRNA_group          0
# spacer_sequence     0
# genomic_coords      0
# start              12
# end                12
# chrom              12
# evalue             12
# dtype: int64

# %% [markdown]
# ### Validate BLAST Results

# %%
# print first 10 sequences to validate BLAST results
group_sequence_df.head(10)
# Out:
#      gRNA_group       spacer_sequence
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG
# 1  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG
# 2    FAM83A_TSS  AACACACCACGGAGGAGTGG
# 3    ZNF593_TSS  AACAGCCCGGCCGGCCAAGG
# 4    ATPIF1_TSS  AACGAGAGACTGCTTGCTGG
# 5     TIPRL_TSS  AACGGCTCGGAAGCCTAGGG
# 6      MYL4_TSS  AAGAAGAAACCGAGAGACGG
# 7      CNBP_TSS  AAGACGGCTCGCAAGGTAGG
# 8      RPS3_TSS  AAGAGGAAGGTGAGCCTCTG
# 9     RPL23_TSS  AAGATGTCGAAGCGAGGTGG

# %%
# read in dataframe of intended target regions
dtypes = {
    'gRNAgroup.start': str,
    'gRNAgroup.stop': str
}

intended_targets_df = pd.read_csv('/iblm/netapp/data1/external/Gasperini2019/suppl/' + \
                                  'GSE120861_gene_gRNAgroup_pair_table.at_scale.txt', sep='\t', dtype=dtypes)
intended_targets_df.head()
# Out:
#   gRNAgroup.chr gRNAgroup.start gRNAgroup.stop   gRNAgroup general_group  \
# 0           NTC             NTC            NTC  bassik_mch           NTC
# 1           NTC             NTC            NTC  bassik_mch           NTC
# 2           NTC             NTC            NTC  bassik_mch           NTC
# 3           NTC             NTC            NTC  bassik_mch           NTC
# 4           NTC             NTC            NTC  bassik_mch           NTC
#
#   chr.targetgene  start.targetgene  stop.targetgene  ENSG.targetgene  \
# 0          chr10          28034777         28034778  ENSG00000150051
# 1          chr10          28287976         28287977  ENSG00000169126
# 2          chr10          28571017         28571018  ENSG00000150054
# 3          chr10          28821422         28821423  ENSG00000095787
# 4          chr10          28966271         28966272  ENSG00000095739
#
#   targetgene_short_name strand.targetgene             pairs
# 0                   MKX                 -    MKX:bassik_mch
# 1                 ARMC4                 -  ARMC4:bassik_mch
# 2                  MPP7                 -   MPP7:bassik_mch
# 3                   WAC                 +    WAC:bassik_mch
# 4                 BAMBI                 +  BAMBI:bassik_mch

# %%
# select only necessary columns from the data frame
intended_targets_df = intended_targets_df.iloc[:, 0:4]
intended_targets_df.head()
# Out:
#   gRNAgroup.chr gRNAgroup.start gRNAgroup.stop   gRNAgroup
# 0           NTC             NTC            NTC  bassik_mch
# 1           NTC             NTC            NTC  bassik_mch
# 2           NTC             NTC            NTC  bassik_mch
# 3           NTC             NTC            NTC  bassik_mch
# 4           NTC             NTC            NTC  bassik_mch

# %%
# get current shape of intended targets
intended_targets_df.shape
# Out:
# (1086564, 4)

# %%
# drop duplicate values prior to merging
intended_targets_df = intended_targets_df.drop_duplicates()

# %%
# get new shape of intended targets after dropping duplicates
intended_targets_df.shape
# Out:
# (6585, 4)

# %%
intended_targets_df.tail()
# Out:
#         gRNAgroup.chr gRNAgroup.start gRNAgroup.stop  \
# 1086199         chr11         5291385        5291386
# 1086272         chr11         5291385        5291386
# 1086345         chr11         5291385        5291386
# 1086418         chr11         5291385        5291386
# 1086491         chr11         5291385        5291386
#
#                                         gRNAgroup
# 1086199              pos_control_HS2_Klann_mosaic
# 1086272  pos_control_Klannchr1_HBG1_HBG1_tss_both
# 1086345          pos_control_mosaic_HB_HBE1_tss_B
# 1086418          pos_control_mosaic_HB_HBE1_tss_A
# 1086491                 pos_control_Klannchr1_HS4

# %%
validate_df = group_sequence_df.merge(intended_targets_df, left_on='gRNA_group', right_on='gRNAgroup')\
              .drop(['genomic_coords', 'gRNAgroup'], axis=1)
validate_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23216/1718388157.py in <module>
# ----> 1 validate_df = group_sequence_df.merge(intended_targets_df, left_on='gRNA_group', right_on='gRNAgroup')\
#       2               .drop(['genomic_coords', 'gRNAgroup'], axis=1)
#       3 validate_df.head()
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['genomic_coords'] not found in axis"

# %%
validate_df.shape
# Out:
# (13163, 9)

# %% [markdown]
# ### Missingness Analysis

# %%
# get count for how many null values there are in the results
group_sequence_df.isna().sum()
# Out:
# gRNA_group          0
# spacer_sequence     0
# genomic_coords      0
# start              12
# end                12
# chrom              12
# evalue             12
# dtype: int64

# %%
# where the null values are coming from 
group_sequence_df[group_sequence_df['start'].isna()]
# Out:
#                gRNA_group       spacer_sequence        genomic_coords  start  \
# 818     chr10.129_top_two  AGACCACACAACACACACAG  [nan, nan, nan, nan]    NaN
# 925    chr10.2135_top_two  AGAGGTGTGTGTGTGTCACG  [nan, nan, nan, nan]    NaN
# 4048    chr15.931_top_two  CTGTTCTCTCTCTCTCTGCC  [nan, nan, nan, nan]    NaN
# 6746    chr2.1666_top_two  TCCTGGACACACACACACAA  [nan, nan, nan, nan]    NaN
# 13097        scrambled_10  ACTGCCTCGCGATTGACTGG  [nan, nan, nan, nan]    NaN
# 13102         scrambled_1  AGCCTAACGATCGGACCGAG  [nan, nan, nan, nan]    NaN
# 13121        scrambled_14  CAGGATCGCTATCAGCACGG  [nan, nan, nan, nan]    NaN
# 13149        scrambled_11  GCGACATTTGGGTCGCGAAG  [nan, nan, nan, nan]    NaN
# 13154         scrambled_8  GCTGTATATCGGCGCCCCGG  [nan, nan, nan, nan]    NaN
# 13155        scrambled_17  GGACGAGTAACCTGCCGGGG  [nan, nan, nan, nan]    NaN
# 13156        scrambled_16  GGCATCGGGCAGACGGGATG  [nan, nan, nan, nan]    NaN
# 13167        scrambled_12  TAAGGGCGACGTTCGGTAAG  [nan, nan, nan, nan]    NaN
#
#        end chrom  evalue
# 818    NaN   NaN     NaN
# 925    NaN   NaN     NaN
# 4048   NaN   NaN     NaN
# 6746   NaN   NaN     NaN
# 13097  NaN   NaN     NaN
# 13102  NaN   NaN     NaN
# 13121  NaN   NaN     NaN
# 13149  NaN   NaN     NaN
# 13154  NaN   NaN     NaN
# 13155  NaN   NaN     NaN
# 13156  NaN   NaN     NaN
# 13167  NaN   NaN     NaN

# %%
# save dataframe and merge with intended targets
null_coords_df = group_sequence_df[group_sequence_df['start'].isna()]
null_coords_df.merge(intended_targets_df, left_on='gRNA_group', right_on='gRNAgroup')\
                     .drop(['gRNAgroup', 'genomic_coords'], axis=1)
# Out:
#             gRNA_group       spacer_sequence  start  end chrom  evalue  \
# 0    chr10.129_top_two  AGACCACACAACACACACAG    NaN  NaN   NaN     NaN
# 1   chr10.2135_top_two  AGAGGTGTGTGTGTGTCACG    NaN  NaN   NaN     NaN
# 2    chr15.931_top_two  CTGTTCTCTCTCTCTCTGCC    NaN  NaN   NaN     NaN
# 3    chr2.1666_top_two  TCCTGGACACACACACACAA    NaN  NaN   NaN     NaN
# 4         scrambled_10  ACTGCCTCGCGATTGACTGG    NaN  NaN   NaN     NaN
# 5          scrambled_1  AGCCTAACGATCGGACCGAG    NaN  NaN   NaN     NaN
# 6         scrambled_14  CAGGATCGCTATCAGCACGG    NaN  NaN   NaN     NaN
# 7         scrambled_11  GCGACATTTGGGTCGCGAAG    NaN  NaN   NaN     NaN
# 8          scrambled_8  GCTGTATATCGGCGCCCCGG    NaN  NaN   NaN     NaN
# 9         scrambled_17  GGACGAGTAACCTGCCGGGG    NaN  NaN   NaN     NaN
# 10        scrambled_16  GGCATCGGGCAGACGGGATG    NaN  NaN   NaN     NaN
# 11        scrambled_12  TAAGGGCGACGTTCGGTAAG    NaN  NaN   NaN     NaN
#
#    gRNAgroup.chr gRNAgroup.start gRNAgroup.stop
# 0          chr10         3710457        3711106
# 1          chr10        71494457       71495376
# 2          chr15        45076438       45076745
# 3           chr2        43155472       43155535
# 4            NTC             NTC            NTC
# 5            NTC             NTC            NTC
# 6            NTC             NTC            NTC
# 7            NTC             NTC            NTC
# 8            NTC             NTC            NTC
# 9            NTC             NTC            NTC
# 10           NTC             NTC            NTC
# 11           NTC             NTC            NTC

# %%
# view NTC groups from original sequences
group_sequence_targets = group_sequence_df.merge(intended_targets_df, left_on='gRNA_group', right_on='gRNAgroup')
group_sequence_targets[group_sequence_targets['gRNAgroup.chr'] == 'NTC'].drop(['gRNAgroup', 'genomic_coords'], axis=1).head()
# Out:
#       gRNA_group       spacer_sequence       start         end  \
# 13062  random_24  AACACAACACACCAAAACTG    101428.0    101409.0
# 13063  random_24  GCAAATGCTTCATCACCCCA  11074158.0  11074139.0
# 13064   random_7  AAGTTGACTCTACATAGCAG  23770078.0  23770097.0
# 13065   random_7  GCTCTAATGAACAGAATGGG  25699943.0  25699924.0
# 13066  random_13  AATATTCTCCCTCATTCTGG  12539494.0  12539475.0
#
#                       chrom  evalue gRNAgroup.chr gRNAgroup.start  \
# 13062  chr9_gl000200_random   0.008           NTC             NTC
# 13063                  chr8   0.008           NTC             NTC
# 13064                  chr8   0.008           NTC             NTC
# 13065                  chr4   0.008           NTC             NTC
# 13066                  chr5   0.008           NTC             NTC
#
#       gRNAgroup.stop
# 13062            NTC
# 13063            NTC
# 13064            NTC
# 13065            NTC
# 13066            NTC

# %%
group_sequence_targets[group_sequence_targets['gRNAgroup.chr'] == 'NTC'].shape
# Out:
# (101, 11)

# %%
ntc_df = group_sequence_targets[group_sequence_targets['gRNAgroup.chr'] == 'NTC']
ntc_df = ntc_df[['chrom', 'start', 'end']].dropna()
ntc_df['start'] = ntc_df['start'].astype(np.int64)
ntc_df['end'] = ntc_df['end'].astype(np.int64)
ntc_df.head()
# Out:
#                       chrom     start       end
# 13062  chr9_gl000200_random    101428    101409
# 13063                  chr8  11074158  11074139
# 13064                  chr8  23770078  23770097
# 13065                  chr4  25699943  25699924
# 13066                  chr5  12539494  12539475

# %%
# write non targeting controls with hits to .bed file (for browser viewing)
ntc_df.to_csv('./../data/ntc_blast_hits.bed', sep='\t', header=False, index=False)

# %% [markdown]
# There are 101 nontargeting controls, but most of them return coordinates from BLAST! The evalues appear to be pretty low for these hits as well, indicating potential off-target effects?
#
# There also appears to be 4 guides that do not get a BLAST hit despite having intended target regions. This could be indicative of low guide specificity?

# %%
# save BLAST output to .csv file
group_sequence_targets.to_csv('./../data/group_sequence_coords.csv', index=False)

# %%
# alternative run to load in resulting data frame from CSV
group_sequence_targets = pd.read_csv('./../data/group_sequence_coords.csv')
group_sequence_targets.head()
# Out:
#      gRNA_group       spacer_sequence                         genomic_coords  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG    [26606551, 26606569, 'chr1', 0.032]
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG    [26606660, 26606641, 'chr1', 0.008]
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   [10530445, 10530427, 'chr11', 0.032]
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG   [10530690, 10530708, 'chr11', 0.032]
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG  [124195027, 124195008, 'chr8', 0.008]
#
#          start          end  chrom  evalue gRNAgroup.chr gRNAgroup.start  \
# 0   26606551.0   26606569.0   chr1   0.032          chr1        26605667
# 1   26606660.0   26606641.0   chr1   0.008          chr1        26605667
# 2   10530445.0   10530427.0  chr11   0.032         chr11        10530735
# 3   10530690.0   10530708.0  chr11   0.032         chr11        10530735
# 4  124195027.0  124195008.0   chr8   0.008          chr8       124191287
#
#   gRNAgroup.stop     gRNAgroup
# 0       26605668  SH3BGRL3_TSS
# 1       26605668  SH3BGRL3_TSS
# 2       10530736  MTRNR2L8_TSS
# 3       10530736  MTRNR2L8_TSS
# 4      124191288    FAM83A_TSS

# %% [markdown]
# ### Viewing Count Data Using scipy.sparse

# %%
# read in count data
count_matrix = mmread('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_at_scale_screen.exprs.mtx')
count_matrix.shape
# Out:
# (13135, 207324)

# %%
# read in column names from corresponding cells file
colnames = []
with open('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_at_scale_screen.cells.txt') as f:
    colnames = f.readlines()

colnames = pd.Series(colnames).str.strip()
colnames
# Out:
# 0         AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2
# 1         AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2
# 2         AAACCTGCAAACAACA-1_1A_1_SI-GA-E2
# 3         AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2
# 4         AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2
#                         ...
# 207319    TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9
# 207320    TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9
# 207321    TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9
# 207322    TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9
# 207323    TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9
# Length: 207324, dtype: object

# %%
# read in index (row names) from corresponding genes file 
rownames = []
with open('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_at_scale_screen.genes.txt') as f:
    rownames = f.readlines()
    
rownames = pd.Series(rownames).str.strip()
rownames
# Out:
# 0        ENSG00000238009
# 1        ENSG00000237683
# 2        ENSG00000228463
# 3        ENSG00000237094
# 4        ENSG00000235373
#               ...
# 13130    ENSG00000215689
# 13131    ENSG00000215781
# 13132    ENSG00000220023
# 13133    ENSG00000215615
# 13134    ENSG00000215699
# Length: 13135, dtype: object

# %%
# create formatted data frame with row and column names
count_data = pd.DataFrame(data=count_matrix.toarray(), index=rownames, columns=colnames)
count_data.head(20)
# Out:
#                  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 1
# ENSG00000228463                                 1
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 0
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 1
# ENSG00000187608                                 1
# ENSG00000188157                                 1
# ENSG00000131591                                 0
# ENSG00000078808                                 4
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 2
#
#                  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 0
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 1
# ENSG00000187608                                 1
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 1
# ENSG00000237094                                 0
# ENSG00000235373                                 1
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 3
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 2
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 1
# ENSG00000160087                                 1
#
#                  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 1
# ENSG00000237094                                 1
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 1
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 1
# ENSG00000187608                                 2
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 1
# ENSG00000176022                                 0
# ENSG00000184163                                 1
# ENSG00000160087                                 3
#
#                  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 1
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 0
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 0
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 1
# ENSG00000184163                                 0
# ENSG00000160087                                 1
#
#                  AAACCTGGTAGCGCAA-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 1
# ENSG00000230368                                 0
# ENSG00000188976                                 1
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 1
# ENSG00000187608                                 1
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 1
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 2
#
#                  AAACCTGGTAGGGACT-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 1
# ENSG00000230368                                 0
# ENSG00000188976                                 1
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 0
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  AAACCTGGTATATGAG-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 1
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 1
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 1
# ENSG00000188157                                 0
# ENSG00000131591                                 1
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  AAACCTGGTCAAAGCG-1_1A_1_SI-GA-E2  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 2
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 0
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 2
#
#                  AAACCTGGTCTTCAAG-1_1A_1_SI-GA-E2  ...  \
# ENSG00000238009                                 0  ...
# ENSG00000237683                                 0  ...
# ENSG00000228463                                 1  ...
# ENSG00000237094                                 0  ...
# ENSG00000235373                                 0  ...
# ENSG00000228327                                 0  ...
# ENSG00000237491                                 0  ...
# ENSG00000225880                                 0  ...
# ENSG00000230368                                 0  ...
# ENSG00000188976                                 1  ...
# ENSG00000187961                                 0  ...
# ENSG00000187583                                 0  ...
# ENSG00000188290                                 0  ...
# ENSG00000187608                                 2  ...
# ENSG00000188157                                 0  ...
# ENSG00000131591                                 0  ...
# ENSG00000078808                                 1  ...
# ENSG00000176022                                 0  ...
# ENSG00000184163                                 0  ...
# ENSG00000160087                                 3  ...
#
#                  TTTGTCACAACGATGG-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 0
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 0
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  TTTGTCACACTTCTGC-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 2
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 4
# ENSG00000187608                                 0
# ENSG00000188157                                 1
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 4
# ENSG00000184163                                 0
# ENSG00000160087                                 2
#
#                  TTTGTCACAGATAATG-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 0
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 2
# ENSG00000187608                                 0
# ENSG00000188157                                 1
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 2
#
#                  TTTGTCACAGCCAGAA-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 1
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 2
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 1
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 1
#
#                  TTTGTCACATTAGGCT-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 1
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 0
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 2
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 1
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 2
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 1
# ENSG00000176022                                 1
# ENSG00000184163                                 0
# ENSG00000160087                                 2
#
#                  TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 3
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 1
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 1
# ENSG00000176022                                 1
# ENSG00000184163                                 0
# ENSG00000160087                                 3
#
#                  TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 1
# ENSG00000228463                                 2
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 1
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 4
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 0
# ENSG00000188157                                 1
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 1
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9  \
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 0
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 1
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 1
# ENSG00000187608                                 0
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 0
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 0
#
#                  TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9
# ENSG00000238009                                 0
# ENSG00000237683                                 0
# ENSG00000228463                                 2
# ENSG00000237094                                 0
# ENSG00000235373                                 0
# ENSG00000228327                                 0
# ENSG00000237491                                 0
# ENSG00000225880                                 0
# ENSG00000230368                                 0
# ENSG00000188976                                 2
# ENSG00000187961                                 0
# ENSG00000187583                                 0
# ENSG00000188290                                 0
# ENSG00000187608                                 2
# ENSG00000188157                                 0
# ENSG00000131591                                 0
# ENSG00000078808                                 2
# ENSG00000176022                                 0
# ENSG00000184163                                 0
# ENSG00000160087                                 1
#
# [20 rows x 207324 columns]

# %%
count_subset = count_data.head(20)
count_subset.sum()
# Out:
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2    11
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2     2
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2     9
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2    11
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2     3
#                                     ..
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9     7
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9     9
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9    10
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9     2
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9     9
# Length: 207324, dtype: int64

# %% [markdown]
# ### Generate Cell-Guide Matrix (which cells contain which guides)

# %%
# read in phenodata file 
colnames = open('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_at_scale.phenoData.colnames.txt') \
           .read().splitlines()

with gzip.open('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_at_scale_screen.phenoData.txt.gz', 'rt') as file:
    phenodata_file = file.read()

with open('./../data/phenodata.txt', 'w') as file:
    file.write(phenodata_file)
    
phenodata_df = pd.read_csv('./../data/phenodata.txt', sep=' ', names=colnames)
phenodata_df.head()
# Out:
#           sample                              cell  total_umis  Size_Factor  \
# 0  1A_1_SI-GA-E2  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2     17572.0     1.009682
# 1  1A_1_SI-GA-E2  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2      8923.0     0.939677
# 2  1A_1_SI-GA-E2  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2     14637.0     0.990803
# 3  1A_1_SI-GA-E2  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2     22798.0     1.036578
# 4  1A_1_SI-GA-E2  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2     10136.0     0.952844
#
#                                                 gene  \
# 0  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# 1  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# 2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# 3  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# 4  chr10.185_top_two_chr10.484_top_two_chr11.4167...
#
#                                             all_gene  \
# 0  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# 1  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# 2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# 3  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# 4  chr10.185_top_two_chr10.484_top_two_chr11.4167...
#
#                                              barcode  read_count  umi_count  \
# 0  AGAAAGCTCCTCCAGTTCAC_TGATCGCTTTGACTGTGACA_ACAA...     14135.0      964.0
# 1  GTAGAGCCTCCAGAACTGTG_AGGTTTATCCAGATGAACTG_CATC...      4329.0      293.0
# 2  CCAAGGCGTCCTCAGACCAG_AGCTCCAGGAAGGACCCCCG_TCAC...     12362.0      884.0
# 3  GGCGTCAGTCGAGGAGTCAG_GCCAGCACTTCAGCTCACCG_GCTG...      7459.0      544.0
# 4  ATAAGGCACTCACATCCACC_GCTTGTCCCTAACACTCAGA_GGGC...     14831.0     1054.0
#
#    proportion  guide_count sample_directory  \
# 0    0.969819         67.0    1A_1_SI-GA-E2
# 1    0.844380         26.0    1A_1_SI-GA-E2
# 2    0.950538         61.0    1A_1_SI-GA-E2
# 3    0.939551         39.0    1A_1_SI-GA-E2
# 4    0.959927         37.0    1A_1_SI-GA-E2
#
#                          ko_barcode_file    id    prep_batch  \
# 0  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 1  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 2  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 3  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 4  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
#
#      within_batch_chip    within_chip_lane  percent.mito
# 0  within_batch_chip_A  within_chip_lane_1      0.058787
# 1  within_batch_chip_A  within_chip_lane_1      0.036087
# 2  within_batch_chip_A  within_chip_lane_1      0.069823
# 3  within_batch_chip_A  within_chip_lane_1      0.026187
# 4  within_batch_chip_A  within_chip_lane_1      0.007991

# %%
# print shape of phenodata data frame
phenodata_df.shape
# Out:
# (207324, 18)

# %%
# check dataframe missingness
phenodata_df.isna().sum()
# Out:
# sample                  0
# cell                    0
# total_umis              0
# Size_Factor             0
# gene                 1527
# all_gene             1527
# barcode              1527
# read_count           1527
# umi_count            1527
# proportion           1527
# guide_count          1527
# sample_directory        0
# ko_barcode_file         0
# id                      0
# prep_batch              0
# within_batch_chip       0
# within_chip_lane        0
# percent.mito            0
# dtype: int64

# %%
# analyze missingness
phenodata_df[phenodata_df['gene'].apply(type) != str]
# Out:
#                sample                              cell  total_umis  \
# 49      1A_1_SI-GA-E2  AAAGCAATCCTACAGA-1_1A_1_SI-GA-E2      3971.0
# 1012    1A_1_SI-GA-E2  AGCGTATCAAACCCAT-1_1A_1_SI-GA-E2      5090.0
# 1031    1A_1_SI-GA-E2  AGCGTCGTCAGGTAAA-1_1A_1_SI-GA-E2      5587.0
# 1034    1A_1_SI-GA-E2  AGCGTCGTCGCGATCG-1_1A_1_SI-GA-E2     16844.0
# 1194    1A_1_SI-GA-E2  AGTAGTCTCAGGATCT-1_1A_1_SI-GA-E2      4958.0
# ...               ...                               ...         ...
# 207126  2B_8_SI-GA-H9  TTCTACATCGAGCCCA-1_2B_8_SI-GA-H9      5833.0
# 207187  2B_8_SI-GA-H9  TTGCCGTGTAGTGAAT-1_2B_8_SI-GA-H9      5955.0
# 207202  2B_8_SI-GA-H9  TTGCGTCGTGAGTGAC-1_2B_8_SI-GA-H9     10269.0
# 207205  2B_8_SI-GA-H9  TTGCGTCTCGTATCAG-1_2B_8_SI-GA-H9      7367.0
# 207290  2B_8_SI-GA-H9  TTTGCGCAGATCCCAT-1_2B_8_SI-GA-H9      5225.0
#
#         Size_Factor gene all_gene barcode  read_count  umi_count  proportion  \
# 49         0.856042  NaN      NaN     NaN         NaN        NaN         NaN
# 1012       0.881687  NaN      NaN     NaN         NaN        NaN         NaN
# 1031       0.891312  NaN      NaN     NaN         NaN        NaN         NaN
# 1034       1.005311  NaN      NaN     NaN         NaN        NaN         NaN
# 1194       0.878973  NaN      NaN     NaN         NaN        NaN         NaN
# ...             ...  ...      ...     ...         ...        ...         ...
# 207126     0.895763  NaN      NaN     NaN         NaN        NaN         NaN
# 207187     0.897901  NaN      NaN     NaN         NaN        NaN         NaN
# 207202     0.954190  NaN      NaN     NaN         NaN        NaN         NaN
# 207205     0.919882  NaN      NaN     NaN         NaN        NaN         NaN
# 207290     0.884392  NaN      NaN     NaN         NaN        NaN         NaN
#
#         guide_count sample_directory                        ko_barcode_file  \
# 49              NaN    1A_1_SI-GA-E2  guide_libraries/1A_1.gRNAcaptured.txt
# 1012            NaN    1A_1_SI-GA-E2  guide_libraries/1A_1.gRNAcaptured.txt
# 1031            NaN    1A_1_SI-GA-E2  guide_libraries/1A_1.gRNAcaptured.txt
# 1034            NaN    1A_1_SI-GA-E2  guide_libraries/1A_1.gRNAcaptured.txt
# 1194            NaN    1A_1_SI-GA-E2  guide_libraries/1A_1.gRNAcaptured.txt
# ...             ...              ...                                    ...
# 207126          NaN    2B_8_SI-GA-H9  guide_libraries/2B_8.gRNAcaptured.txt
# 207187          NaN    2B_8_SI-GA-H9  guide_libraries/2B_8.gRNAcaptured.txt
# 207202          NaN    2B_8_SI-GA-H9  guide_libraries/2B_8.gRNAcaptured.txt
# 207205          NaN    2B_8_SI-GA-H9  guide_libraries/2B_8.gRNAcaptured.txt
# 207290          NaN    2B_8_SI-GA-H9  guide_libraries/2B_8.gRNAcaptured.txt
#
#           id    prep_batch    within_batch_chip    within_chip_lane  \
# 49      1A_1  prep_batch_1  within_batch_chip_A  within_chip_lane_1
# 1012    1A_1  prep_batch_1  within_batch_chip_A  within_chip_lane_1
# 1031    1A_1  prep_batch_1  within_batch_chip_A  within_chip_lane_1
# 1034    1A_1  prep_batch_1  within_batch_chip_A  within_chip_lane_1
# 1194    1A_1  prep_batch_1  within_batch_chip_A  within_chip_lane_1
# ...      ...           ...                  ...                 ...
# 207126  2B_8  prep_batch_2  within_batch_chip_B  within_chip_lane_8
# 207187  2B_8  prep_batch_2  within_batch_chip_B  within_chip_lane_8
# 207202  2B_8  prep_batch_2  within_batch_chip_B  within_chip_lane_8
# 207205  2B_8  prep_batch_2  within_batch_chip_B  within_chip_lane_8
# 207290  2B_8  prep_batch_2  within_batch_chip_B  within_chip_lane_8
#
#         percent.mito
# 49          0.016117
# 1012        0.027112
# 1031        0.017720
# 1034        0.061149
# 1194        0.041549
# ...              ...
# 207126      0.013544
# 207187      0.051889
# 207202      0.028727
# 207205      0.004344
# 207290      0.014928
#
# [1527 rows x 18 columns]

# %%
# drop nan values fromd data frame
phenodata_df = phenodata_df.dropna()
phenodata_df.head()
# Out:
#           sample                              cell  total_umis  Size_Factor  \
# 0  1A_1_SI-GA-E2  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2     17572.0     1.009682
# 1  1A_1_SI-GA-E2  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2      8923.0     0.939677
# 2  1A_1_SI-GA-E2  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2     14637.0     0.990803
# 3  1A_1_SI-GA-E2  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2     22798.0     1.036578
# 4  1A_1_SI-GA-E2  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2     10136.0     0.952844
#
#                                                 gene  \
# 0  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# 1  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# 2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# 3  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# 4  chr10.185_top_two_chr10.484_top_two_chr11.4167...
#
#                                             all_gene  \
# 0  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# 1  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# 2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# 3  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# 4  chr10.185_top_two_chr10.484_top_two_chr11.4167...
#
#                                              barcode  read_count  umi_count  \
# 0  AGAAAGCTCCTCCAGTTCAC_TGATCGCTTTGACTGTGACA_ACAA...     14135.0      964.0
# 1  GTAGAGCCTCCAGAACTGTG_AGGTTTATCCAGATGAACTG_CATC...      4329.0      293.0
# 2  CCAAGGCGTCCTCAGACCAG_AGCTCCAGGAAGGACCCCCG_TCAC...     12362.0      884.0
# 3  GGCGTCAGTCGAGGAGTCAG_GCCAGCACTTCAGCTCACCG_GCTG...      7459.0      544.0
# 4  ATAAGGCACTCACATCCACC_GCTTGTCCCTAACACTCAGA_GGGC...     14831.0     1054.0
#
#    proportion  guide_count sample_directory  \
# 0    0.969819         67.0    1A_1_SI-GA-E2
# 1    0.844380         26.0    1A_1_SI-GA-E2
# 2    0.950538         61.0    1A_1_SI-GA-E2
# 3    0.939551         39.0    1A_1_SI-GA-E2
# 4    0.959927         37.0    1A_1_SI-GA-E2
#
#                          ko_barcode_file    id    prep_batch  \
# 0  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 1  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 2  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 3  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 4  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
#
#      within_batch_chip    within_chip_lane  percent.mito
# 0  within_batch_chip_A  within_chip_lane_1      0.058787
# 1  within_batch_chip_A  within_chip_lane_1      0.036087
# 2  within_batch_chip_A  within_chip_lane_1      0.069823
# 3  within_batch_chip_A  within_chip_lane_1      0.026187
# 4  within_batch_chip_A  within_chip_lane_1      0.007991

# %%
# get new data frame shape
phenodata_df.shape
# Out:
# (205797, 18)

# %%
def get_guide_names(guides):
    '''regex function to separate guide names'''
    
    guide_list = re.findall(r"[A-Za-z0-9]*\_TSS|chr[A-Z0-9]{1,2}\.\w*top_two|chr[A-Z0-9]{1,2}\.\w*second_two", guides)
    return guide_list

# %%
# get guide names for each cell
phenodata_df['guides'] = phenodata_df['gene'].apply(get_guide_names)
test = phenodata_df.head()
test['guides'].apply(len)
# Out:
# 0    67
# 1    26
# 2    61
# 3    39
# 4    37
# Name: guides, dtype: int64

# %%
# split guide sequences for each cell
phenodata_df['sequences'] = phenodata_df['barcode'].str.split('_')
phenodata_df.head()
# Out:
#           sample                              cell  total_umis  Size_Factor  \
# 0  1A_1_SI-GA-E2  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2     17572.0     1.009682
# 1  1A_1_SI-GA-E2  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2      8923.0     0.939677
# 2  1A_1_SI-GA-E2  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2     14637.0     0.990803
# 3  1A_1_SI-GA-E2  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2     22798.0     1.036578
# 4  1A_1_SI-GA-E2  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2     10136.0     0.952844
#
#                                                 gene  \
# 0  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# 1  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# 2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# 3  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# 4  chr10.185_top_two_chr10.484_top_two_chr11.4167...
#
#                                             all_gene  \
# 0  chr10.845_top_two_chr1.11183_top_two_chr1.1129...
# 1  chr1.12695_top_two_chr11.3294_top_two_chr1.679...
# 2  ALDH1A2_TSS_BRI3_TSS_chr10.1918_top_two_chr10....
# 3  C16orf91_TSS_chr1.11332_top_two_chr1.1933_top_...
# 4  chr10.185_top_two_chr10.484_top_two_chr11.4167...
#
#                                              barcode  read_count  umi_count  \
# 0  AGAAAGCTCCTCCAGTTCAC_TGATCGCTTTGACTGTGACA_ACAA...     14135.0      964.0
# 1  GTAGAGCCTCCAGAACTGTG_AGGTTTATCCAGATGAACTG_CATC...      4329.0      293.0
# 2  CCAAGGCGTCCTCAGACCAG_AGCTCCAGGAAGGACCCCCG_TCAC...     12362.0      884.0
# 3  GGCGTCAGTCGAGGAGTCAG_GCCAGCACTTCAGCTCACCG_GCTG...      7459.0      544.0
# 4  ATAAGGCACTCACATCCACC_GCTTGTCCCTAACACTCAGA_GGGC...     14831.0     1054.0
#
#    proportion  guide_count sample_directory  \
# 0    0.969819         67.0    1A_1_SI-GA-E2
# 1    0.844380         26.0    1A_1_SI-GA-E2
# 2    0.950538         61.0    1A_1_SI-GA-E2
# 3    0.939551         39.0    1A_1_SI-GA-E2
# 4    0.959927         37.0    1A_1_SI-GA-E2
#
#                          ko_barcode_file    id    prep_batch  \
# 0  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 1  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 2  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 3  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
# 4  guide_libraries/1A_1.gRNAcaptured.txt  1A_1  prep_batch_1
#
#      within_batch_chip    within_chip_lane  percent.mito  \
# 0  within_batch_chip_A  within_chip_lane_1      0.058787
# 1  within_batch_chip_A  within_chip_lane_1      0.036087
# 2  within_batch_chip_A  within_chip_lane_1      0.069823
# 3  within_batch_chip_A  within_chip_lane_1      0.026187
# 4  within_batch_chip_A  within_chip_lane_1      0.007991
#
#                                               guides  \
# 0  [chr10.845_top_two, chr1.11183_top_two, chr1.1...
# 1  [chr1.12695_top_two, chr11.3294_top_two, chr1....
# 2  [ALDH1A2_TSS, BRI3_TSS, chr10.1918_top_two, ch...
# 3  [C16orf91_TSS, chr1.11332_top_two, chr1.1933_t...
# 4  [chr10.185_top_two, chr10.484_top_two, chr11.4...
#
#                                            sequences
# 0  [AGAAAGCTCCTCCAGTTCAC, TGATCGCTTTGACTGTGACA, A...
# 1  [GTAGAGCCTCCAGAACTGTG, AGGTTTATCCAGATGAACTG, C...
# 2  [CCAAGGCGTCCTCAGACCAG, AGCTCCAGGAAGGACCCCCG, T...
# 3  [GGCGTCAGTCGAGGAGTCAG, GCCAGCACTTCAGCTCACCG, G...
# 4  [ATAAGGCACTCACATCCACC, GCTTGTCCCTAACACTCAGA, G...

# %%
# select only columns necessary for analysis
phenodata_df = phenodata_df[['cell', 'guides', 'sequences']]
phenodata_df.head()
# Out:
#                                cell  \
# 0  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2
# 1  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2
# 2  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2
# 3  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2
# 4  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2
#
#                                               guides  \
# 0  [chr10.845_top_two, chr1.11183_top_two, chr1.1...
# 1  [chr1.12695_top_two, chr11.3294_top_two, chr1....
# 2  [ALDH1A2_TSS, BRI3_TSS, chr10.1918_top_two, ch...
# 3  [C16orf91_TSS, chr1.11332_top_two, chr1.1933_t...
# 4  [chr10.185_top_two, chr10.484_top_two, chr11.4...
#
#                                            sequences
# 0  [AGAAAGCTCCTCCAGTTCAC, TGATCGCTTTGACTGTGACA, A...
# 1  [GTAGAGCCTCCAGAACTGTG, AGGTTTATCCAGATGAACTG, C...
# 2  [CCAAGGCGTCCTCAGACCAG, AGCTCCAGGAAGGACCCCCG, T...
# 3  [GGCGTCAGTCGAGGAGTCAG, GCCAGCACTTCAGCTCACCG, G...
# 4  [ATAAGGCACTCACATCCACC, GCTTGTCCCTAACACTCAGA, G...

# %%
# test building cell-guide matrix on subset of larger data frame
phenodata_test_df = phenodata_df.head(5)
phenodata_test_df
# Out:
#                                cell  \
# 0  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2
# 1  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2
# 2  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2
# 3  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2
# 4  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2
#
#                                               guides  \
# 0  [chr10.845_top_two, chr1.11183_top_two, chr1.1...
# 1  [chr1.12695_top_two, chr11.3294_top_two, chr1....
# 2  [ALDH1A2_TSS, BRI3_TSS, chr10.1918_top_two, ch...
# 3  [C16orf91_TSS, chr1.11332_top_two, chr1.1933_t...
# 4  [chr10.185_top_two, chr10.484_top_two, chr11.4...
#
#                                            sequences
# 0  [AGAAAGCTCCTCCAGTTCAC, TGATCGCTTTGACTGTGACA, A...
# 1  [GTAGAGCCTCCAGAACTGTG, AGGTTTATCCAGATGAACTG, C...
# 2  [CCAAGGCGTCCTCAGACCAG, AGCTCCAGGAAGGACCCCCG, T...
# 3  [GGCGTCAGTCGAGGAGTCAG, GCCAGCACTTCAGCTCACCG, G...
# 4  [ATAAGGCACTCACATCCACC, GCTTGTCCCTAACACTCAGA, G...

# %%
guide_sequences = pd.Series(phenodata_test_df['sequences'].sum()).unique()

# %%
cell_names = phenodata_test_df['cell']
cell_names
# Out:
# 0    AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2
# 1    AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2
# 2    AAACCTGCAAACAACA-1_1A_1_SI-GA-E2
# 3    AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2
# 4    AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2
# Name: cell, dtype: object

# %%
pd.Series(guide_sequences).isin(phenodata_test_df['sequences'].loc[0]).astype(np.int64)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 225    0
# 226    0
# 227    0
# 228    0
# 229    0
# Length: 230, dtype: int64

# %%
def guides_present(cell_guide_list):
    return pd.Series(guide_sequences).isin(cell_guide_list).astype(np.int64)

# %%
test_cell_guide_matrix = phenodata_test_df['sequences'].apply(guides_present)
test_cell_guide_matrix.index = cell_names
test_cell_guide_matrix.columns = guide_sequences
test_cell_guide_matrix = test_cell_guide_matrix.T
test_cell_guide_matrix
# Out:
# cell                  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 1
# TGATCGCTTTGACTGTGACA                                 1
# ACAATAAAGAACAGAACACA                                 1
# GTAAATTGAGACCTCAGGAG                                 1
# TCTTCCCCCCACCAATAACA                                 1
# ...                                                ...
# GGAGGAATCATCCTACCGGG                                 0
# GCTGCAACTGGATGACACAG                                 0
# GCTAGGCCTCCATATTCCTA                                 0
# CCCGGGCCGAAGGTGCGAGG                                 0
# GGAGTACGCTCGGGAGCCCG                                 0
#
# cell                  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
# ...                                                ...
# GGAGGAATCATCCTACCGGG                                 0
# GCTGCAACTGGATGACACAG                                 0
# GCTAGGCCTCCATATTCCTA                                 0
# CCCGGGCCGAAGGTGCGAGG                                 0
# GGAGTACGCTCGGGAGCCCG                                 0
#
# cell                  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
# ...                                                ...
# GGAGGAATCATCCTACCGGG                                 0
# GCTGCAACTGGATGACACAG                                 0
# GCTAGGCCTCCATATTCCTA                                 0
# CCCGGGCCGAAGGTGCGAGG                                 0
# GGAGTACGCTCGGGAGCCCG                                 0
#
# cell                  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
# ...                                                ...
# GGAGGAATCATCCTACCGGG                                 0
# GCTGCAACTGGATGACACAG                                 0
# GCTAGGCCTCCATATTCCTA                                 0
# CCCGGGCCGAAGGTGCGAGG                                 0
# GGAGTACGCTCGGGAGCCCG                                 0
#
# cell                  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
# ...                                                ...
# GGAGGAATCATCCTACCGGG                                 1
# GCTGCAACTGGATGACACAG                                 1
# GCTAGGCCTCCATATTCCTA                                 1
# CCCGGGCCGAAGGTGCGAGG                                 1
# GGAGTACGCTCGGGAGCCCG                                 1
#
# [230 rows x 5 columns]

# %%
test_cell_guide_matrix.to_hdf('./../data/test_cell_guide_matrix.h5', key='df', mode='w')

# %% [markdown]
# ### Read in Cell-Guide Matrix

# %%
# read in cell-guide matrix
cell_guide_matrix = pd.read_hdf('./../data/cell_guide_matrix.h5')
cell_guide_matrix.head()
# Out:
# cell                  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 1
# TGATCGCTTTGACTGTGACA                                 1
# ACAATAAAGAACAGAACACA                                 1
# GTAAATTGAGACCTCAGGAG                                 1
# TCTTCCCCCCACCAATAACA                                 1
#
# cell                  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTAGCGCAA-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTAGGGACT-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTATATGAG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTCAAAGCG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 1
#
# cell                  AAACCTGGTCTTCAAG-1_1A_1_SI-GA-E2  ...  \
# AGAAAGCTCCTCCAGTTCAC                                 0  ...
# TGATCGCTTTGACTGTGACA                                 0  ...
# ACAATAAAGAACAGAACACA                                 0  ...
# GTAAATTGAGACCTCAGGAG                                 0  ...
# TCTTCCCCCCACCAATAACA                                 0  ...
#
# cell                  TTTGTCACAACGATGG-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACACTTCTGC-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACAGATAATG-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACAGCCAGAA-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACATTAGGCT-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# [5 rows x 205797 columns]

# %%
# get shape of cell guide matrix
cell_guide_matrix.shape
# Out:
# (13186, 205797)

# %%
group_sequence_coords = pd.read_csv('./../data/group_sequence_coords.csv')
group_sequence_coords.head()
# Out:
#      gRNA_group       spacer_sequence                         genomic_coords  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG    [26606551, 26606569, 'chr1', 0.032]
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG    [26606660, 26606641, 'chr1', 0.008]
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   [10530445, 10530427, 'chr11', 0.032]
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG   [10530690, 10530708, 'chr11', 0.032]
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG  [124195027, 124195008, 'chr8', 0.008]
#
#          start          end  chrom  evalue gRNAgroup.chr gRNAgroup.start  \
# 0   26606551.0   26606569.0   chr1   0.032          chr1        26605667
# 1   26606660.0   26606641.0   chr1   0.008          chr1        26605667
# 2   10530445.0   10530427.0  chr11   0.032         chr11        10530735
# 3   10530690.0   10530708.0  chr11   0.032         chr11        10530735
# 4  124195027.0  124195008.0   chr8   0.008          chr8       124191287
#
#   gRNAgroup.stop     gRNAgroup
# 0       26605668  SH3BGRL3_TSS
# 1       26605668  SH3BGRL3_TSS
# 2       10530736  MTRNR2L8_TSS
# 3       10530736  MTRNR2L8_TSS
# 4      124191288    FAM83A_TSS

# %%
genes = pd.read_csv('./../data/genes_coords.csv')
genes.head()
# Out:
#   chr.targetgene  start.targetgene  stop.targetgene  ENSG.targetgene  \
# 0          chr10          28034777         28034778  ENSG00000150051
# 1          chr10          28287976         28287977  ENSG00000169126
# 2          chr10          28571017         28571018  ENSG00000150054
# 3          chr10          28821422         28821423  ENSG00000095787
# 4          chr10          28966271         28966272  ENSG00000095739
#
#   targetgene_short_name
# 0                   MKX
# 1                 ARMC4
# 2                  MPP7
# 3                   WAC
# 4                 BAMBI

# %%
def find_close_genes(guide_row):
    '''find close genes given guide information'''
    
    # get guide information
    guide_start = guide_row['start']
    guide_end = guide_row['end']
    guide_chrom = guide_row['chrom']
    
    # filter genes that match chromosome
    filtered_genes = genes[genes['chr.targetgene'] == guide_chrom]
    
    # filter genes within range of 100kb
    left = guide_start - 100000
    right = guide_end + 100000
    filtered_genes = filtered_genes[(filtered_genes['start.targetgene'] > left) & (filtered_genes['stop.targetgene'] < right)]
    
    return list(filtered_genes['ENSG.targetgene'])

# %%
# filter necessary columns
group_sequence_coords = group_sequence_coords[['gRNA_group', 'spacer_sequence', 'start', 'end', 'chrom']]
group_sequence_coords.head()
# Out:
#      gRNA_group       spacer_sequence        start          end  chrom
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG   26606551.0   26606569.0   chr1
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG   26606660.0   26606641.0   chr1
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   10530445.0   10530427.0  chr11
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG   10530690.0   10530708.0  chr11
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG  124195027.0  124195008.0   chr8

# %%
# get proximal genes for each guide sequence
group_sequence_coords['proximal_genes'] = group_sequence_coords.apply(find_close_genes, axis=1)
group_sequence_coords.head()
# Out:
#      gRNA_group       spacer_sequence        start          end  chrom  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG   26606551.0   26606569.0   chr1
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG   26606660.0   26606641.0   chr1
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   10530445.0   10530427.0  chr11
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG   10530690.0   10530708.0  chr11
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG  124195027.0  124195008.0   chr8
#
#                                       proximal_genes
# 0  [ENSG00000188782, ENSG00000130695, ENSG0000014...
# 1  [ENSG00000188782, ENSG00000130695, ENSG0000014...
# 2  [ENSG00000133805, ENSG00000255823, ENSG0000011...
# 3  [ENSG00000133805, ENSG00000255823, ENSG0000011...
# 4  [ENSG00000147689, ENSG00000189376, ENSG0000016...

# %%
# explode dataframe to get guide-gene pairs
guide_gene_pairs = group_sequence_coords.explode('proximal_genes', ignore_index=True)
guide_gene_pairs.head()
# Out:
#      gRNA_group       spacer_sequence       start         end chrom  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 1  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 2  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 3  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 4  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
#
#     proximal_genes
# 0  ENSG00000188782
# 1  ENSG00000130695
# 2  ENSG00000142669
# 3  ENSG00000158062
# 4  ENSG00000169442

# %%
# get shape of guide gene pairs
guide_gene_pairs.shape
# Out:
# (34817, 6)

# %% [markdown]
# ### Baseline GLM (Generalized Linear Model)

# %%
guide_gene_pairs.isna().sum()
# Out:
# gRNA_group            0
# spacer_sequence       0
# start                12
# end                  12
# chrom                12
# proximal_genes     3021
# dtype: int64

# %%
guide_gene_pairs = guide_gene_pairs.dropna()
guide_gene_pairs.head()
# Out:
#      gRNA_group       spacer_sequence       start         end chrom  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 1  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 2  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 3  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
# 4  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG  26606551.0  26606569.0  chr1
#
#     proximal_genes
# 0  ENSG00000188782
# 1  ENSG00000130695
# 2  ENSG00000142669
# 3  ENSG00000158062
# 4  ENSG00000169442

# %%
guide_gene_pairs.shape
# Out:
# (31796, 6)

# %%
input_vector = cell_guide_matrix.loc[guide_gene_pairs['spacer_sequence'][0]]
output_vector = count_data.loc[guide_gene_pairs['proximal_genes'][1]]
# Out:
# AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2    0
# AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2    0
# AAACCTGCAAACAACA-1_1A_1_SI-GA-E2    0
# AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2    0
# AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2    0
#                                    ..
# TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9    0
# TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9    0
# TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9    0
# TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9    1
# TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9    0
# Name: ENSG00000130695, Length: 207324, dtype: int64

# %% [markdown]
# ### Determine Guide Pairs

# %%
# get guide sequences
guide_sequences = pd.Series(cell_guide_matrix.index)
guide_sequences.head()
# Out:
# 0    AGAAAGCTCCTCCAGTTCAC
# 1    TGATCGCTTTGACTGTGACA
# 2    ACAATAAAGAACAGAACACA
# 3    GTAAATTGAGACCTCAGGAG
# 4    TCTTCCCCCCACCAATAACA
# dtype: object

# %%
# read in group sequence coordinates file
group_sequence_coords = pd.read_csv('./../data/group_sequence_coords.csv')
group_sequence_coords.head()
# Out:
#      gRNA_group       spacer_sequence                         genomic_coords  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG    [26606551, 26606569, 'chr1', 0.032]
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG    [26606660, 26606641, 'chr1', 0.008]
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   [10530445, 10530427, 'chr11', 0.032]
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG   [10530690, 10530708, 'chr11', 0.032]
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG  [124195027, 124195008, 'chr8', 0.008]
#
#          start          end  chrom  evalue gRNAgroup.chr gRNAgroup.start  \
# 0   26606551.0   26606569.0   chr1   0.032          chr1        26605667
# 1   26606660.0   26606641.0   chr1   0.008          chr1        26605667
# 2   10530445.0   10530427.0  chr11   0.032         chr11        10530735
# 3   10530690.0   10530708.0  chr11   0.032         chr11        10530735
# 4  124195027.0  124195008.0   chr8   0.008          chr8       124191287
#
#   gRNAgroup.stop     gRNAgroup
# 0       26605668  SH3BGRL3_TSS
# 1       26605668  SH3BGRL3_TSS
# 2       10530736  MTRNR2L8_TSS
# 3       10530736  MTRNR2L8_TSS
# 4      124191288    FAM83A_TSS

# %%
# match guide sequences to genomic coordinates
(group_sequence_coords[guide_sequences.loc[5] == group_sequence_coords['spacer_sequence']]['start'])
# Out:
# 1963    244486508.0
# Name: start, dtype: float64

# %%
def match_genomic_coordinates(spacer_sequence):
    '''helper function to match spacer sequence to corresponding genomic coordinates'''
    
    guide_row = group_sequence_coords[group_sequence_coords['spacer_sequence'] == spacer_sequence]
    return guide_row['start'], guide_row['end']

# %%
group_sequence_coords = group_sequence_coords[['gRNA_group', 'spacer_sequence', 'start', 'end', 'chrom']]
group_sequence_coords.head()
# Out:
#      gRNA_group       spacer_sequence        start          end  chrom
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG   26606551.0   26606569.0   chr1
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG   26606660.0   26606641.0   chr1
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG   10530445.0   10530427.0  chr11
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG   10530690.0   10530708.0  chr11
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG  124195027.0  124195008.0   chr8

# %%
# create dataframe of guide sequences
guide_sequences_df = pd.DataFrame(guide_sequences, columns=['spacer_sequence'])
guide_sequences_df.head()
# Out:
#         spacer_sequence
# 0  AGAAAGCTCCTCCAGTTCAC
# 1  TGATCGCTTTGACTGTGACA
# 2  ACAATAAAGAACAGAACACA
# 3  GTAAATTGAGACCTCAGGAG
# 4  TCTTCCCCCCACCAATAACA

# %%
# merge guide sequences with group sequence coordinates
merged_df = guide_sequences_df.merge(group_sequence_coords, how='left')
merged_df.head()
# Out:
#         spacer_sequence          gRNA_group        start          end  chrom
# 0  AGAAAGCTCCTCCAGTTCAC   chr10.845_top_two   23345017.0   23345036.0  chr10
# 1  TGATCGCTTTGACTGTGACA  chr1.11183_top_two  205720521.0  205720502.0   chr1
# 2  ACAATAAAGAACAGAACACA  chr1.11293_top_two  207020873.0  207020892.0   chr1
# 3  GTAAATTGAGACCTCAGGAG  chr11.1791_top_two   34847978.0   34847959.0  chr11
# 4  TCTTCCCCCCACCAATAACA  chr1.12598_top_two  235029683.0  235029664.0   chr1

# %%
# check dataframe shape
merged_df.shape
# Out:
# (13186, 5)

# %%
# analyze missingness in dataset
merged_df.isna().sum()
# Out:
# spacer_sequence     0
# gRNA_group         26
# start              38
# end                38
# chrom              38
# dtype: int64

# %%
# drop nan values (cannot be used for analysis)
merged_df = merged_df.dropna()

# %%
# check new shape of dataset
merged_df.shape
# Out:
# (13148, 5)

# %%
# convert datatypes for merged dataframe
merged_df['start'] = merged_df['start'].astype(np.int64)
merged_df['end'] = merged_df['end'].astype(np.int64)
merged_df.head()
# Out:
#         spacer_sequence          gRNA_group      start        end  chrom
# 0  AGAAAGCTCCTCCAGTTCAC   chr10.845_top_two   23345017   23345036  chr10
# 1  TGATCGCTTTGACTGTGACA  chr1.11183_top_two  205720521  205720502   chr1
# 2  ACAATAAAGAACAGAACACA  chr1.11293_top_two  207020873  207020892   chr1
# 3  GTAAATTGAGACCTCAGGAG  chr11.1791_top_two   34847978   34847959  chr11
# 4  TCTTCCCCCCACCAATAACA  chr1.12598_top_two  235029683  235029664   chr1

# %%
# test to find all guides within 1MB for first start site
test_chrom = merged_df.loc[0]['chrom']
test_filter = merged_df[merged_df['chrom'] == 'chr10']
test_start = merged_df.loc[0]['start']
test_filter = test_filter[test_filter['start'] != test_start]
test_diffs = np.abs(test_start - test_filter['start'])
test_matches = test_diffs <= 1000000
list(test_filter[test_matches]['spacer_sequence'])
# Out:
# ['AAAGTTTGTTGAAAGTGGCG',
#  'CCTCAGTGCATAAGGCCAAT',
#  'GTTTGCTGAAGATAAATGCA',
#  'AACACAAGCAATGCGACAAC',
#  'AGACCGCCGTGAAGACCCCG',
#  'GCTTCTGTGTGACTCATACG',
#  'GTAGAGCTCAGATAAGAGCT',
#  'GAAAGCTCCTCCAGTTCACG',
#  'CATGTTGGAGATGTGCCTTA',
#  'CTGCCAAGCTCAATTGTCCT',
#  'GTCGCCATCTTGTTTATGTT',
#  'GCCCGGAGGAGAAGCGTGAG',
#  'GGTCACGGCGCGCTCACAAG',
#  'AGAAAAAGCAATCTTGACTG',
#  'TAGGTGCTGGCTGAAAAACG',
#  'GTAGGAGTCCCTCCAGGAGA',
#  'GTAAATCACGTGGCCATGCC',
#  'TCTATTGGTCTGTTAGGTGC',
#  'GACAAAGTCACTCTGTCCCA',
#  'ATATGATCGTTTGGTCACAA',
#  'GTGACGCGTGAAATGTAACG',
#  'GAGACAGCTAAGTGACCAAA',
#  'CATGGCCACGTGATTTACTC',
#  'GGCAGACTATTGCTGCTGGA',
#  'TGGAGGGATTCTGTACAGAG',
#  'AGGACAATTGAGCTTGGCAG',
#  'TTGTTTATGTTGGGTTTGGC',
#  'ATAGGCGGCTGACCACCCAG',
#  'TACATCTGTTCACATTTCAC',
#  'TGAACAGATGTATACACTTC',
#  'CCATAGACTGGGTATTTCAT',
#  'AAAAAGACGGAGGAAGTGCA',
#  'ACTTAAGGTAGTAAACTGAT']

# %%
def find_proximal_guides(guide_row):
    '''function to return list of proximal guides given guide information'''
    
    # get guide chromsome and start information 
    guide_start = guide_row['start']
    guide_chrom = guide_row['chrom']
    
    # filter dataframe for chromosome and remove current guide
    filtered_guides = merged_df[merged_df['chrom'] == guide_chrom]
    filtered_guides = filtered_guides[filtered_guides['start'] != guide_start]
    
    # get 1MB proximal guide matches and return list of proximal guides
    bp_diffs = np.abs(guide_start - filtered_guides['start'])
    bp_matches = bp_diffs <= 1000000
    return list(filtered_guides[bp_matches]['spacer_sequence'])

# %%
# get proximal guides (within 1MB) for every guide in the data frame
merged_df['proximal_guides'] = merged_df.apply(find_proximal_guides, axis=1)
merged_df.head()
# Out:
#         spacer_sequence          gRNA_group      start        end  chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC   chr10.845_top_two   23345017   23345036  chr10
# 1  TGATCGCTTTGACTGTGACA  chr1.11183_top_two  205720521  205720502   chr1
# 2  ACAATAAAGAACAGAACACA  chr1.11293_top_two  207020873  207020892   chr1
# 3  GTAAATTGAGACCTCAGGAG  chr11.1791_top_two   34847978   34847959  chr11
# 4  TCTTCCCCCCACCAATAACA  chr1.12598_top_two  235029683  235029664   chr1
#
#                                      proximal_guides
# 0  [AAAGTTTGTTGAAAGTGGCG, CCTCAGTGCATAAGGCCAAT, G...
# 1  [CTAGGTGGTGTGGGGAGTGA, TCTTGACTAACAGGACCCCA, G...
# 2  [GTTGTCCTTCAGGGACAGTG, GCCAGCACTTCAGCTCACCG, G...
# 3  [CCCGGGCCGAAGGTGCGAGG, TTACTGGGAGGGCATCAGAG, G...
# 4  [GAGAACCTATTCCTGTCCAG, GAAGGAAGTGGGCTTCCACA, T...

# %% [markdown]
# ### Determine Gene-Guide Pairs

# %%
test_guide = merged_df.loc[0]
test_guide
# Out:
# spacer_sequence                                 AGAAAGCTCCTCCAGTTCAC
# gRNA_group                                         chr10.845_top_two
# start                                                       23345017
# end                                                         23345036
# chrom                                                          chr10
# proximal_guides    [AAAGTTTGTTGAAAGTGGCG, CCTCAGTGCATAAGGCCAAT, G...
# Name: 0, dtype: object

# %%
test_guide_start = test_guide['start']
pd.Series(test_guide['proximal_guides'])
# Out:
# 0     AAAGTTTGTTGAAAGTGGCG
# 1     CCTCAGTGCATAAGGCCAAT
# 2     GTTTGCTGAAGATAAATGCA
# 3     AACACAAGCAATGCGACAAC
# 4     AGACCGCCGTGAAGACCCCG
# 5     GCTTCTGTGTGACTCATACG
# 6     GTAGAGCTCAGATAAGAGCT
# 7     GAAAGCTCCTCCAGTTCACG
# 8     CATGTTGGAGATGTGCCTTA
# 9     CTGCCAAGCTCAATTGTCCT
# 10    GTCGCCATCTTGTTTATGTT
# 11    GCCCGGAGGAGAAGCGTGAG
# 12    GGTCACGGCGCGCTCACAAG
# 13    AGAAAAAGCAATCTTGACTG
# 14    TAGGTGCTGGCTGAAAAACG
# 15    GTAGGAGTCCCTCCAGGAGA
# 16    GTAAATCACGTGGCCATGCC
# 17    TCTATTGGTCTGTTAGGTGC
# 18    GACAAAGTCACTCTGTCCCA
# 19    ATATGATCGTTTGGTCACAA
# 20    GTGACGCGTGAAATGTAACG
# 21    GAGACAGCTAAGTGACCAAA
# 22    CATGGCCACGTGATTTACTC
# 23    GGCAGACTATTGCTGCTGGA
# 24    TGGAGGGATTCTGTACAGAG
# 25    AGGACAATTGAGCTTGGCAG
# 26    TTGTTTATGTTGGGTTTGGC
# 27    ATAGGCGGCTGACCACCCAG
# 28    TACATCTGTTCACATTTCAC
# 29    TGAACAGATGTATACACTTC
# 30    CCATAGACTGGGTATTTCAT
# 31    AAAAAGACGGAGGAAGTGCA
# 32    ACTTAAGGTAGTAAACTGAT
# dtype: object

# %%
# explode to get guide pairs in individual rows
exploded_df = merged_df.explode('proximal_guides', ignore_index=True)
exploded_df.head()
# Out:
#         spacer_sequence         gRNA_group     start       end  chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036  chr10
# 1  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036  chr10
# 2  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036  chr10
# 3  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036  chr10
# 4  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036  chr10
#
#         proximal_guides
# 0  AAAGTTTGTTGAAAGTGGCG
# 1  CCTCAGTGCATAAGGCCAAT
# 2  GTTTGCTGAAGATAAATGCA
# 3  AACACAAGCAATGCGACAAC
# 4  AGACCGCCGTGAAGACCCCG

# %%
exploded_df.shape
# Out:
# (291647, 6)

# %%
# get start and end coordinates for proximal guides
join_df = merged_df.drop(['proximal_guides'], axis=1)
guide_pairs_df = exploded_df.merge(join_df, left_on='proximal_guides', right_on='spacer_sequence')
guide_pairs_df.head()
# Out:
#       spacer_sequence_x          gRNA_group_x   start_x     end_x chrom_x  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036   chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940   chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624   chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121   chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219   chr10
#
#         proximal_guides     spacer_sequence_y       gRNA_group_y   start_y  \
# 0  AAAGTTTGTTGAAAGTGGCG  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685
# 1  AAAGTTTGTTGAAAGTGGCG  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685
# 2  AAAGTTTGTTGAAAGTGGCG  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685
# 3  AAAGTTTGTTGAAAGTGGCG  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685
# 4  AAAGTTTGTTGAAAGTGGCG  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685
#
#       end_y chrom_y
# 0  22519666   chr10
# 1  22519666   chr10
# 2  22519666   chr10
# 3  22519666   chr10
# 4  22519666   chr10

# %%
# rename columns for guide pairs
colnames = ['g1_spacer_sequence', 'g1_gRNA_group', 'g1_start', 'g1_end', 'g1_chrom', 'g1_proximal',
            'g2_spacer_sequence', 'g2_gRNA_group', 'g2_start', 'g2_end', 'g2_chrom']
guide_pairs_df.columns = colnames
guide_pairs_df = guide_pairs_df.drop(['g1_proximal'], axis=1)
guide_pairs_df.head()
# Out:
#      g1_spacer_sequence         g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036    chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940    chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624    chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121    chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 1  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 2  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 3  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 4  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10

# %%
# get leftmost and rightmost coordinates for each guide pair
guide_pairs_df['left'] = guide_pairs_df[['g1_start', 'g2_start']].min(axis=1)
guide_pairs_df['right'] = guide_pairs_df[['g1_end', 'g2_end']].max(axis=1)
guide_pairs_df.head()
# Out:
#      g1_spacer_sequence         g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036    chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940    chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624    chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121    chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 1  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 2  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 3  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 4  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right
# 0  22519685  23345036
# 1  22422921  22519666
# 2  22306605  22519666
# 3  22519685  23144121
# 4  22518200  22519666

# %%
# add 1 megabase region for finding genes
guide_pairs_df['left'] = guide_pairs_df['left'] - 1000000
guide_pairs_df['right'] = guide_pairs_df['right'] + 1000000
guide_pairs_df.head()
# Out:
#      g1_spacer_sequence         g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036    chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940    chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624    chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121    chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 1  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 2  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 3  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 4  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right
# 0  21519685  24345036
# 1  21422921  23519666
# 2  21306605  23519666
# 3  21519685  24144121
# 4  21518200  23519666

# %%
# read in dataframe of intended target regions
dtypes = {
    'gRNAgroup.start': str,
    'gRNAgroup.stop': str
}

intended_targets_df = pd.read_csv('/iblm/netapp/data1/external/Gasperini2019/suppl/' + \
                                  'GSE120861_gene_gRNAgroup_pair_table.at_scale.txt', sep='\t', dtype=dtypes)
intended_targets_df.head()
# Out:
#   gRNAgroup.chr gRNAgroup.start gRNAgroup.stop   gRNAgroup general_group  \
# 0           NTC             NTC            NTC  bassik_mch           NTC
# 1           NTC             NTC            NTC  bassik_mch           NTC
# 2           NTC             NTC            NTC  bassik_mch           NTC
# 3           NTC             NTC            NTC  bassik_mch           NTC
# 4           NTC             NTC            NTC  bassik_mch           NTC
#
#   chr.targetgene  start.targetgene  stop.targetgene  ENSG.targetgene  \
# 0          chr10          28034777         28034778  ENSG00000150051
# 1          chr10          28287976         28287977  ENSG00000169126
# 2          chr10          28571017         28571018  ENSG00000150054
# 3          chr10          28821422         28821423  ENSG00000095787
# 4          chr10          28966271         28966272  ENSG00000095739
#
#   targetgene_short_name strand.targetgene             pairs
# 0                   MKX                 -    MKX:bassik_mch
# 1                 ARMC4                 -  ARMC4:bassik_mch
# 2                  MPP7                 -   MPP7:bassik_mch
# 3                   WAC                 +    WAC:bassik_mch
# 4                 BAMBI                 +  BAMBI:bassik_mch

# %%
gene_df = intended_targets_df[['chr.targetgene', 'start.targetgene', 'stop.targetgene', 
                               'ENSG.targetgene', 'targetgene_short_name']]
gene_df.head()
# Out:
#   chr.targetgene  start.targetgene  stop.targetgene  ENSG.targetgene  \
# 0          chr10          28034777         28034778  ENSG00000150051
# 1          chr10          28287976         28287977  ENSG00000169126
# 2          chr10          28571017         28571018  ENSG00000150054
# 3          chr10          28821422         28821423  ENSG00000095787
# 4          chr10          28966271         28966272  ENSG00000095739
#
#   targetgene_short_name
# 0                   MKX
# 1                 ARMC4
# 2                  MPP7
# 3                   WAC
# 4                 BAMBI

# %%
# get shape of gene dataframe
gene_df.shape
# Out:
# (1086564, 5)

# %%
# drop duplicates and get new dataframe shape 
gene_df = gene_df.drop_duplicates()
gene_df.shape
# Out:
# (18389, 5)

# %%
test_data = guide_pairs_df.loc[0]
test_data
# Out:
# g1_spacer_sequence    AGAAAGCTCCTCCAGTTCAC
# g1_gRNA_group            chr10.845_top_two
# g1_start                          23345017
# g1_end                            23345036
# g1_chrom                             chr10
# g2_spacer_sequence    AAAGTTTGTTGAAAGTGGCG
# g2_gRNA_group            chr10.791_top_two
# g2_start                          22519685
# g2_end                            22519666
# g2_chrom                             chr10
# left                              21519685
# right                             24345036
# Name: 0, dtype: object

# %%
test_matches = gene_df[(gene_df['start.targetgene'] > test_data['left']) & (gene_df['stop.targetgene'] < test_data['right'])]
test_gene_names = list(test_matches['ENSG.targetgene'])
test_short_gene_names = list(test_matches['targetgene_short_name'])

# %%
# write current dataframes to CSV files
gene_df.to_csv('./../data/genes_coords.csv', index=False)
guide_pairs_df.to_csv('./../data/guide_pairs.csv', index=False)

# %%
def get_proximal_genes(guide_pair_row):
    '''function to get proximal genes and short gene names given guide pair information'''
    
    gene_matches = gene_df[(gene_df['start.targetgene'] > guide_pair_row['left']) & 
                           (gene_df['stop.targetgene'] < guide_pair_row['right'])]
    gene_names = list(gene_matches['ENSG.targetgene'])
    short_gene_names = list(gene_matches['targetgene_short_name'])
    return pd.Series([gene_names, short_gene_names])

# %%
test_output = guide_pairs_df.head().apply(get_proximal_genes, axis=1)
pd.concat([guide_pairs_df.head(), test_output], axis=1)
# Out:
#      g1_spacer_sequence         g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036    chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940    chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624    chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121    chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 1  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 2  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 3  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 4  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right                                                  0  \
# 0  21519685  24345036  [ENSG00000204682, ENSG00000180592, ENSG0000007...
# 1  21422921  23519666  [ENSG00000204683, ENSG00000204682, ENSG0000018...
# 2  21306605  23519666  [ENSG00000204683, ENSG00000204682, ENSG0000018...
# 3  21519685  24144121  [ENSG00000204682, ENSG00000180592, ENSG0000007...
# 4  21518200  23519666  [ENSG00000204682, ENSG00000180592, ENSG0000007...
#
#                                                    1
# 0  [CASC10, SKIDA1, MLLT10, DNAJC1, EBLN1, COMMD3...
# 1  [C10orf113, CASC10, SKIDA1, MLLT10, DNAJC1, EB...
# 2  [C10orf113, CASC10, SKIDA1, MLLT10, DNAJC1, EB...
# 3  [CASC10, SKIDA1, MLLT10, DNAJC1, EBLN1, COMMD3...
# 4  [CASC10, SKIDA1, MLLT10, DNAJC1, EBLN1, COMMD3...

# %%
guide_pairs_df.shape
# Out:
# (291584, 12)

# %%
gene_df.shape
# Out:
# (18389, 5)

# %%
guide_pairs_genes = pd.read_csv('./../data/guide_pairs_proximal_genes.csv')
guide_pairs_genes.head()
# Out:
#      g1_spacer_sequence         g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036    chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940    chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624    chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121    chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 1  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 2  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 3  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 4  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right                                proximal_gene_names  \
# 0  21519685  24345036  ['ENSG00000204682', 'ENSG00000180592', 'ENSG00...
# 1  21422921  23519666  ['ENSG00000204683', 'ENSG00000204682', 'ENSG00...
# 2  21306605  23519666  ['ENSG00000204683', 'ENSG00000204682', 'ENSG00...
# 3  21519685  24144121  ['ENSG00000204682', 'ENSG00000180592', 'ENSG00...
# 4  21518200  23519666  ['ENSG00000204682', 'ENSG00000180592', 'ENSG00...
#
#                            proximal_short_gene_names
# 0  ['CASC10', 'SKIDA1', 'MLLT10', 'DNAJC1', 'EBLN...
# 1  ['C10orf113', 'CASC10', 'SKIDA1', 'MLLT10', 'D...
# 2  ['C10orf113', 'CASC10', 'SKIDA1', 'MLLT10', 'D...
# 3  ['CASC10', 'SKIDA1', 'MLLT10', 'DNAJC1', 'EBLN...
# 4  ['CASC10', 'SKIDA1', 'MLLT10', 'DNAJC1', 'EBLN...

# %%
# get shape of dataframe
guide_pairs_genes.shape
# Out:
# (291584, 14)

# %%
guide_pairs_genes = guide_pairs_genes.drop(['proximal_short_gene_names'], axis=1)

# %%
guide_pairs_genes['proximal_gene_names'] = guide_pairs_genes['proximal_gene_names']\
                                           .apply(lambda x: x.strip('[]').split(', '))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1c28b4642a03> in <module>
# ----> 1 guide_pairs_genes['proximal_gene_names'] = guide_pairs_genes['proximal_gene_names']\
#       2                                            .apply(lambda x: x.strip('[]').split(', '))
#       3 guide_pairs_genes.head()
#
# ~/miniconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-8-1c28b4642a03> in <lambda>(x)
#       1 guide_pairs_genes['proximal_gene_names'] = guide_pairs_genes['proximal_gene_names']\
# ----> 2                                            .apply(lambda x: x.strip('[]').split(', '))
#       3 guide_pairs_genes.head()
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
guide_pairs_genes.head()
# Out:
#      g1_spacer_sequence         g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC     chr10.845_top_two  23345017  23345036    chr10
# 1  CCTCAGTGCATAAGGCCAAT  chr10.786_second_two  22422921  22422940    chr10
# 2  GCCTCCCAATAACCCTACAA  chr10.779_second_two  22306605  22306624    chr10
# 3  GTTTGCTGAAGATAAATGCA     chr10.836_top_two  23144140  23144121    chr10
# 4  AGACCGCCGTGAAGACCCCG     chr10.790_top_two  22518200  22518219    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 1  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 2  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 3  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 4  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right                                proximal_gene_names
# 0  21519685  24345036  ['ENSG00000204682', 'ENSG00000180592', 'ENSG00...
# 1  21422921  23519666  ['ENSG00000204683', 'ENSG00000204682', 'ENSG00...
# 2  21306605  23519666  ['ENSG00000204683', 'ENSG00000204682', 'ENSG00...
# 3  21519685  24144121  ['ENSG00000204682', 'ENSG00000180592', 'ENSG00...
# 4  21518200  23519666  ['ENSG00000204682', 'ENSG00000180592', 'ENSG00...

# %%
guide_pairs_genes = guide_pairs_genes.explode('proximal_gene_names')

# %%
guide_pairs_genes.shape
# Out:
# (83720570, 13)

# %%
guide_pairs_genes.head()
# Out:
#      g1_spacer_sequence      g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right proximal_gene_names
# 0  21519685  24345036   'ENSG00000204682'
# 0  21519685  24345036   'ENSG00000180592'
# 0  21519685  24345036   'ENSG00000078403'
# 0  21519685  24345036   'ENSG00000136770'
# 0  21519685  24345036   'ENSG00000223601'

# %%
guide_pairs_genes['proximal_gene_names'] = guide_pairs_genes['proximal_gene_names'].apply(lambda x: x.strip("'"))
guide_pairs_genes.head()
# Out:
#      g1_spacer_sequence      g1_gRNA_group  g1_start    g1_end g1_chrom  \
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
# 0  AGAAAGCTCCTCCAGTTCAC  chr10.845_top_two  23345017  23345036    chr10
#
#      g2_spacer_sequence      g2_gRNA_group  g2_start    g2_end g2_chrom  \
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
# 0  AAAGTTTGTTGAAAGTGGCG  chr10.791_top_two  22519685  22519666    chr10
#
#        left     right proximal_gene_names
# 0  21519685  24345036     ENSG00000204682
# 0  21519685  24345036     ENSG00000180592
# 0  21519685  24345036     ENSG00000078403
# 0  21519685  24345036     ENSG00000136770
# 0  21519685  24345036     ENSG00000223601

# %%
guide_pairs_genes.to_csv('./../data/guide_pairs_genes.csv', index=False)

# %%
test_series = pd.Series([1, 2, 3, 4, 5], index=['A', 'B', 'C', 'D', 'E'])
test_series
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
test_series_2 = pd.Series([6, 7, 8, 9, 10], index=['C', 'D', 'E', 'F', 'G'])
test_series_2
# Out:
# C     6
# D     7
# E     8
# F     9
# G    10
# dtype: int64

# %%
test_df_1 = pd.DataFrame(test_series)
test_df_2 = pd.DataFrame(test_series_2)
test_df_1
# Out:
#    0
# A  1
# B  2
# C  3
# D  4
# E  5

# %%
test_df_2
# Out:
#     0
# C   6
# D   7
# E   8
# F   9
# G  10

# %%
test_df_1.merge(test_df_2, left_index=True, right_index=True)
# Out:
#    0_x  0_y
# C    3    6
# D    4    7
# E    5    8

# %%
test_series[test_series.index.isin(test_series_2.index)]
# Out:
# C    3
# D    4
# E    5
# dtype: int64

# %%
input_vec = pd.read_csv('../data/test_input_vector.csv')
output_vec = pd.read_csv('../data/test_output_vector.csv')
input_vec
# Out:
#                                     cell  AAACCGCTCCCGAGCACGGG
# 0       AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2                     0
# 1       AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2                     0
# 2       AAACCTGCAAACAACA-1_1A_1_SI-GA-E2                     0
# 3       AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2                     0
# 4       AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2                     0
# ...                                  ...                   ...
# 205792  TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9                     0
# 205793  TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9                     0
# 205794  TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9                     0
# 205795  TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9                     0
# 205796  TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9                     0
#
# [205797 rows x 2 columns]

# %%
guide_gene_pairs = pd.read_csv('../data/guide_gene_pairs.csv')
guide_gene_pairs.iloc[0]['spacer_sequence']
# Out:
# 'AAACCGCTCCCGAGCACGGG'

# %%
cell_guide_matrix = pd.read_hdf('../data/cell_guide_matrix.h5')
cell_guide_matrix.head()
# Out:
# cell                  AAACCTGAGAGGTACC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 1
# TGATCGCTTTGACTGTGACA                                 1
# ACAATAAAGAACAGAACACA                                 1
# GTAAATTGAGACCTCAGGAG                                 1
# TCTTCCCCCCACCAATAACA                                 1
#
# cell                  AAACCTGAGTCAATAG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGCAAACAACA-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGCACTTCTGC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGCATGTAGTC-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTAGCGCAA-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTAGGGACT-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTATATGAG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  AAACCTGGTCAAAGCG-1_1A_1_SI-GA-E2  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 1
#
# cell                  AAACCTGGTCTTCAAG-1_1A_1_SI-GA-E2  ...  \
# AGAAAGCTCCTCCAGTTCAC                                 0  ...
# TGATCGCTTTGACTGTGACA                                 0  ...
# ACAATAAAGAACAGAACACA                                 0  ...
# GTAAATTGAGACCTCAGGAG                                 0  ...
# TCTTCCCCCCACCAATAACA                                 0  ...
#
# cell                  TTTGTCACAACGATGG-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACACTTCTGC-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACAGATAATG-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACAGCCAGAA-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCACATTAGGCT-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTACCTACA-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTATCACCA-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTTCAGACT-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCAGTTCTGTTT-1_2B_8_SI-GA-H9  \
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# cell                  TTTGTCATCAAAGTAG-1_2B_8_SI-GA-H9
# AGAAAGCTCCTCCAGTTCAC                                 0
# TGATCGCTTTGACTGTGACA                                 0
# ACAATAAAGAACAGAACACA                                 0
# GTAAATTGAGACCTCAGGAG                                 0
# TCTTCCCCCCACCAATAACA                                 0
#
# [5 rows x 205797 columns]

# %%
test_df_1['test'] = [3, 3, 3, 3, 3]
test_df_1.apply(sum, axis=1)
# Out:
# A    4
# B    5
# C    6
# D    7
# E    8
# dtype: int64
