# %% [markdown]
# # Create H5 Structure for Gasperini Pilot Data
#
# Author: Karthik Guruvayurappan

# %%
library(Matrix)
library(rhdf5)
library(monocle)
# Out:
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
# ...

# %%
# create matrix to hold Gasperini data
h5createFile('/iblm/netapp/data1/external/Gasperini2019/processed/gasperini_pilot_data.h5')
# Out:
# [1] TRUE

# %%
cds<- readRDS('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_at_scale_screen.cds.rds')
cds

# %%
head(cds)

# %%
covariates <- pData(cds)
covariates <- covariates[, c('sample', 'cell', 'prep.batch', 'percent_mito', 'guide.count')]
head(covariates)
# Out:
# Error in `[.data.frame`(covariates, , c("sample", "cell", "prep.batch", : undefined columns selected
# Traceback:
#
# 1. covariates[, c("sample", "cell", "prep.batch", "percent.mito",
#  .     "guide.count")]
# 2. `[.data.frame`(covariates, , c("sample", "cell", "prep.batch",
#  .     "percent.mito", "guide.count"))
# 3. stop("undefined columns selected")

# %%
for (name in colnames(covariates)) {
    print(name)
}
# Out:
# [1] "sample"
# [1] "cell"
# [1] "total_umis"
# [1] "Size_Factor"
# [1] "gene"
# [1] "all_gene"
# [1] "barcode"
# [1] "read_count"
# [1] "umi_count"
# [1] "proportion"
# [1] "guide_count"
# [1] "sample_directory"
# [1] "ko_barcode_file"
# [1] "sample_name"
# [1] "scrambled_1"
# [1] "scrambled_2"
# [1] "scrambled_3"
# [1] "scrambled_4"
# [1] "scrambled_5"
# [1] "scrambled_6"
# [1] "scrambled_7"
# [1] "scrambled_8"
# [1] "scrambled_9"
# [1] "scrambled_10"
# [1] "scrambled_11"
# [1] "scrambled_12"
# [1] "scrambled_13"
# [1] "scrambled_14"
# [1] "scrambled_15"
# [1] "scrambled_16"
# [1] "scrambled_17"
# [1] "scrambled_18"
# [1] "scrambled_19"
# [1] "scrambled_20"
# [1] "scrambled_21"
# [1] "scrambled_22"
# [1] "scrambled_23"
# [1] "scrambled_24"
# [1] "scrambled_25"
# [1] "random_1"
# [1] "random_2"
# [1] "random_3"
# [1] "random_4"
# [1] "random_5"
# [1] "random_6"
# [1] "random_7"
# [1] "random_8"
# [1] "random_9"
# [1] "random_10"
# [1] "random_11"
# [1] "random_12"
# [1] "random_13"
# ...
