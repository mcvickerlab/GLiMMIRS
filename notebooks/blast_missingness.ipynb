# %% [markdown]
# # BLAST Missingness Analysis

# %%
# computational packages
import numpy as np
import pandas as pd

# %%
# load in group sequence data frame to get all spacer sequences
group_sequence_df = pd.read_csv('/iblm/netapp/data1/external/Gasperini2019/suppl/GSE120861_grna_groups.at_scale.txt', sep='\t', 
                                names=['gRNA_group', 'spacer_sequence'])
group_sequence_df.head()
# Out:
#      gRNA_group       spacer_sequence
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG
# 1  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG
# 2    FAM83A_TSS  AACACACCACGGAGGAGTGG
# 3    ZNF593_TSS  AACAGCCCGGCCGGCCAAGG
# 4    ATPIF1_TSS  AACGAGAGACTGCTTGCTGG

# %%
# isolate spacer sequences
spacer_sequences = group_sequence_df['spacer_sequence']
spacer_sequences.head()
# Out:
# 0    AAACCGCTCCCGAGCACGGG
# 1    AAATAGTGGGAAGATTCGTG
# 2    AACACACCACGGAGGAGTGG
# 3    AACAGCCCGGCCGGCCAAGG
# 4    AACGAGAGACTGCTTGCTGG
# Name: spacer_sequence, dtype: object

# %%
def get_blast_info(spacer_sequence):
    '''function to get BLAST output information given a spacer sequence'''
    
    # define column names for BLAST output
    colnames = ['chrom', 'evalue', 'start', 'end', 'length', 'pident', 'nident', 'mismatch', 'gapopen', 
                'gaps', 'bitscore']
    
    # read in output dataframe
    blast_output = pd.read_csv('./../blast/output/' + spacer_sequence + '_extra_info.tsv', sep='\t',
                               names=colnames)
    
    # return first hit if BLAST has at least one hit
    if blast_output.shape[0] > 0:
        return blast_output.iloc[0]
    
    # return nan values if there are no hits
    else:
        return pd.Series(data=[np.nan] * blast_output.shape[1], index=colnames)

# %%
# get BLAST output for all spacer sequences
blast_output_df = spacer_sequences.apply(get_blast_info)
blast_output_df.head()
# Out:
#    chrom  evalue        start          end  length  pident  nident  mismatch  \
# 0   chr1   0.032   26606551.0   26606569.0    19.0   100.0    19.0       0.0
# 1  chr11   0.032   10530445.0   10530427.0    19.0   100.0    19.0       0.0
# 2   chr8   0.008  124195027.0  124195008.0    20.0   100.0    20.0       0.0
# 3   chr1   0.008   26496467.0   26496448.0    20.0   100.0    20.0       0.0
# 4   chr1   0.032   28562642.0   28562660.0    19.0   100.0    19.0       0.0
#
#    gapopen  gaps  bitscore
# 0      0.0   0.0      38.2
# 1      0.0   0.0      38.2
# 2      0.0   0.0      40.1
# 3      0.0   0.0      40.1
# 4      0.0   0.0      38.2

# %%
group_sequence_blast_df = pd.concat([group_sequence_df, blast_output_df], axis=1)
group_sequence_blast_df.head()
# Out:
#      gRNA_group       spacer_sequence  chrom  evalue        start  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG   chr1   0.032   26606551.0
# 1  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG  chr11   0.032   10530445.0
# 2    FAM83A_TSS  AACACACCACGGAGGAGTGG   chr8   0.008  124195027.0
# 3    ZNF593_TSS  AACAGCCCGGCCGGCCAAGG   chr1   0.008   26496467.0
# 4    ATPIF1_TSS  AACGAGAGACTGCTTGCTGG   chr1   0.032   28562642.0
#
#            end  length  pident  nident  mismatch  gapopen  gaps  bitscore
# 0   26606569.0    19.0   100.0    19.0       0.0      0.0   0.0      38.2
# 1   10530427.0    19.0   100.0    19.0       0.0      0.0   0.0      38.2
# 2  124195008.0    20.0   100.0    20.0       0.0      0.0   0.0      40.1
# 3   26496448.0    20.0   100.0    20.0       0.0      0.0   0.0      40.1
# 4   28562660.0    19.0   100.0    19.0       0.0      0.0   0.0      38.2

# %%
# read in dataframe of intended target regions
dtypes = {
    'gRNAgroup.start': str,
    'gRNAgroup.stop': str
}

intended_targets_df = pd.read_csv('/iblm/netapp/data1/external/Gasperini2019/suppl/' + \
                                  'GSE120861_gene_gRNAgroup_pair_table.at_scale.txt', sep='\t', dtype=dtypes)
intended_targets_df.head()
# Out:
#   gRNAgroup.chr gRNAgroup.start gRNAgroup.stop   gRNAgroup general_group  \
# 0           NTC             NTC            NTC  bassik_mch           NTC
# 1           NTC             NTC            NTC  bassik_mch           NTC
# 2           NTC             NTC            NTC  bassik_mch           NTC
# 3           NTC             NTC            NTC  bassik_mch           NTC
# 4           NTC             NTC            NTC  bassik_mch           NTC
#
#   chr.targetgene  start.targetgene  stop.targetgene  ENSG.targetgene  \
# 0          chr10          28034777         28034778  ENSG00000150051
# 1          chr10          28287976         28287977  ENSG00000169126
# 2          chr10          28571017         28571018  ENSG00000150054
# 3          chr10          28821422         28821423  ENSG00000095787
# 4          chr10          28966271         28966272  ENSG00000095739
#
#   targetgene_short_name strand.targetgene             pairs
# 0                   MKX                 -    MKX:bassik_mch
# 1                 ARMC4                 -  ARMC4:bassik_mch
# 2                  MPP7                 -   MPP7:bassik_mch
# 3                   WAC                 +    WAC:bassik_mch
# 4                 BAMBI                 +  BAMBI:bassik_mch

# %%
# select only necessary columns from the data frame
intended_targets_df = intended_targets_df.iloc[:, 0:4]
intended_targets_df.head()
# Out:
#   gRNAgroup.chr gRNAgroup.start gRNAgroup.stop   gRNAgroup
# 0           NTC             NTC            NTC  bassik_mch
# 1           NTC             NTC            NTC  bassik_mch
# 2           NTC             NTC            NTC  bassik_mch
# 3           NTC             NTC            NTC  bassik_mch
# 4           NTC             NTC            NTC  bassik_mch

# %%
# drop duplicate values prior to merging
intended_targets_df = intended_targets_df.drop_duplicates()

# %%
# view some intended target regions
intended_targets_df.tail()
# Out:
#         gRNAgroup.chr gRNAgroup.start gRNAgroup.stop  \
# 1086199         chr11         5291385        5291386
# 1086272         chr11         5291385        5291386
# 1086345         chr11         5291385        5291386
# 1086418         chr11         5291385        5291386
# 1086491         chr11         5291385        5291386
#
#                                         gRNAgroup
# 1086199              pos_control_HS2_Klann_mosaic
# 1086272  pos_control_Klannchr1_HBG1_HBG1_tss_both
# 1086345          pos_control_mosaic_HB_HBE1_tss_B
# 1086418          pos_control_mosaic_HB_HBE1_tss_A
# 1086491                 pos_control_Klannchr1_HS4

# %%
# merge BLAST output with intended targets
blast_targets_df = group_sequence_blast_df.merge(intended_targets_df, left_on='gRNA_group', 
                                                 right_on='gRNAgroup')
blast_targets_df = blast_targets_df.drop(['gRNAgroup'], axis=1)
blast_targets_df.head()
# Out:
#      gRNA_group       spacer_sequence  chrom  evalue        start  \
# 0  SH3BGRL3_TSS  AAACCGCTCCCGAGCACGGG   chr1   0.032   26606551.0
# 1  SH3BGRL3_TSS  CGCAGGCCGCTCATGCTGGG   chr1   0.008   26606660.0
# 2  MTRNR2L8_TSS  AAATAGTGGGAAGATTCGTG  chr11   0.032   10530445.0
# 3  MTRNR2L8_TSS  AAGCTGTTCGGTAGTAAGGG  chr11   0.032   10530690.0
# 4    FAM83A_TSS  AACACACCACGGAGGAGTGG   chr8   0.008  124195027.0
#
#            end  length  pident  nident  mismatch  gapopen  gaps  bitscore  \
# 0   26606569.0    19.0   100.0    19.0       0.0      0.0   0.0      38.2
# 1   26606641.0    20.0   100.0    20.0       0.0      0.0   0.0      40.1
# 2   10530427.0    19.0   100.0    19.0       0.0      0.0   0.0      38.2
# 3   10530708.0    19.0   100.0    19.0       0.0      0.0   0.0      38.2
# 4  124195008.0    20.0   100.0    20.0       0.0      0.0   0.0      40.1
#
#   gRNAgroup.chr gRNAgroup.start gRNAgroup.stop
# 0          chr1        26605667       26605668
# 1          chr1        26605667       26605668
# 2         chr11        10530735       10530736
# 3         chr11        10530735       10530736
# 4          chr8       124191287      124191288

# %%
# filter for non-targeting controls
ntc_df = blast_targets_df[blast_targets_df['gRNAgroup.chr'] == 'NTC']
ntc_df
# Out:
#       gRNA_group       spacer_sequence                 chrom  evalue  \
# 13062  random_24  AACACAACACACCAAAACTG  chr9_gl000200_random   0.008
# 13063  random_24  GCAAATGCTTCATCACCCCA                  chr8   0.008
# 13064   random_7  AAGTTGACTCTACATAGCAG                  chr8   0.008
# 13065   random_7  GCTCTAATGAACAGAATGGG                  chr4   0.008
# 13066  random_13  AATATTCTCCCTCATTCTGG                  chr5   0.008
# ...          ...                   ...                   ...     ...
# 13158  random_12  TCCGCAGTCAAAAGACCGAG  chr9_gl000200_random   0.008
# 13159  random_21  TCAGGGGTCGATCTTTAACC                 chr19   0.008
# 13160  random_21  TCTAATCTCAGCTACTTGGG     chrX_jh720454_fix   0.008
# 13161  random_15  TGAACAATACTCCAGTACAT  chr9_gl000200_random   0.008
# 13162  random_15  TGCATCTTCTGAAATGGCAG                  chr6   0.008
#
#             start         end  length  pident  nident  mismatch  gapopen  \
# 13062    101428.0    101409.0    20.0   100.0    20.0       0.0      0.0
# 13063  11074158.0  11074139.0    20.0   100.0    20.0       0.0      0.0
# 13064  23770078.0  23770097.0    20.0   100.0    20.0       0.0      0.0
# 13065  25699943.0  25699924.0    20.0   100.0    20.0       0.0      0.0
# 13066  12539494.0  12539475.0    20.0   100.0    20.0       0.0      0.0
# ...           ...         ...     ...     ...     ...       ...      ...
# 13158    102182.0    102163.0    20.0   100.0    20.0       0.0      0.0
# 13159  58326812.0  58326793.0    20.0   100.0    20.0       0.0      0.0
# 13160    366887.0    366868.0    20.0   100.0    20.0       0.0      0.0
# 13161    101059.0    101040.0    20.0   100.0    20.0       0.0      0.0
# 13162  23838644.0  23838625.0    20.0   100.0    20.0       0.0      0.0
#
#        gaps  bitscore gRNAgroup.chr gRNAgroup.start gRNAgroup.stop
# 13062   0.0      40.1           NTC             NTC            NTC
# 13063   0.0      40.1           NTC             NTC            NTC
# 13064   0.0      40.1           NTC             NTC            NTC
# 13065   0.0      40.1           NTC             NTC            NTC
# 13066   0.0      40.1           NTC             NTC            NTC
# ...     ...       ...           ...             ...            ...
# 13158   0.0      40.1           NTC             NTC            NTC
# 13159   0.0      40.1           NTC             NTC            NTC
# 13160   0.0      40.1           NTC             NTC            NTC
# 13161   0.0      40.1           NTC             NTC            NTC
# 13162   0.0      40.1           NTC             NTC            NTC
#
# [101 rows x 16 columns]

# %%
# write output to a CSV file
ntc_df.to_csv('./../data/ntc_df.csv', index=False)
